# %% [markdown]
# ## Setup

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12


# Code to visualize the execution graph in the jupyter notebook
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = b"<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
import tensorflow as tf

# %%
def plot_image(image,title=None):
    plt.figure()
    plt.imshow(image, cmap="gray", interpolation="nearest")
    if title is not None:
        plt.title(title)
    plt.axis("off")

def plot_color_image(image):
    plt.imshow(image.astype(np.uint8),interpolation="nearest")
    plt.axis("off")
    
def getActivations(layer,stimuli):
    units = sess.run(layer,feed_dict={X:np.reshape(stimuli,[1,784],order='F')})
    plotNNFilter(units)

# visualize convolution activations
def plotNNFilter(units):
    filters = units.shape[3]
    plt.figure(1, figsize=(20,20))
    n_columns = 6
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.imshow(units[0,:,:,i], interpolation="nearest", cmap="gray")

# visualize convolution kernels
def plotConvLayerWeights(conv_layer_name, sess):
    kernel = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, conv_layer_name)[0]
    weights = sess.run(kernel)
    print(kernel.shape)
    
    n_filters = int(kernel.shape[3])
    n_base_layers = int(kernel.shape[2])
    plt.figure(figsize=(20,20))
    for j in range(n_base_layers):
        for i in range(n_filters):
            plt.subplot(n_base_layers, n_filters, j * n_filters + i + 1)
            plt.xticks([])
            plt.yticks([])
            plt.imshow(weights[:,:,j,i].reshape(kernel.shape[0],kernel.shape[1]), cmap='gray', interpolation='nearest')
            plt.title(str(i+1))

# %% [markdown]
# ## Load MNIST

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ### Select 1459 and 023678 from MNIST

# %%
def prepare_data():
    global  dataset_1459_train, \
            dataset_023678_train, \
            X_1459_train, \
            y_1459_train, \
            X_1459_test, \
            y_1459_test, \
            X_023678_test, \
            y_023678_test, \
            X_023678_train, \
            y_023678_train
    mask_1459_train = np.logical_or.reduce([mnist.train.labels == v for v in [1,4,5,9]])
    mask_1459_test  = np.logical_or.reduce([mnist.test.labels  == v for v in [1,4,5,9]])
    X_1459_train = np.compress(np.array(mask_1459_train), mnist.train.images, axis=0)
    _, y_1459_train = np.unique(mnist.train.labels[mask_1459_train], return_inverse=True) # 1,4,5,9 to 0,1,2,3
    dataset_1459_train = tf.contrib.data.Dataset.from_tensor_slices((X_1459_train,y_1459_train))

    X_1459_test = np.compress(np.array(mask_1459_test), mnist.test.images, axis=0)
    _, y_1459_test = np.unique(mnist.test.labels[mask_1459_test], return_inverse=True)

    mask_023678_train = np.logical_or.reduce([mnist.train.labels == v for v in [0,2,3,6,7,8]])
    mask_023678_test  = np.logical_or.reduce([mnist.test.labels  == v for v in [0,2,3,6,7,8]])
    X_023678_train = np.compress(np.array(mask_023678_train), mnist.train.images, axis=0)
    _, y_023678_train = np.unique(mnist.train.labels[mask_023678_train], return_inverse=True) # 1,4,5,9 to 0,1,2,3
    dataset_023678_train = tf.contrib.data.Dataset.from_tensor_slices((X_023678_train,y_023678_train))

    X_023678_test = np.compress(np.array(mask_023678_test), mnist.test.images, axis=0)
    _, y_023678_test = np.unique(mnist.test.labels[mask_023678_test], return_inverse=True)

prepare_data()

# for example
plot_image(X_1459_test[2].reshape(28,28),title=y_1459_test[2])
plot_image(X_023678_test[2].reshape(28,28),title=y_023678_test[2])
# Out:
# WARNING:tensorflow:From <ipython-input-5-c9cee9b3a086>:7: from_tensor_slices (from tensorflow.contrib.data.python.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.from_tensor_slices()`.

# %% [markdown]
# # Convolutional Network

# %% [markdown]
# ### Construct Graph

# %%
height = 28
width = 28
channels = 1
n_inputs = height * width
n_outputs = 4

reset_graph()
prepare_data()

# inputs layer
with tf.name_scope("inputs"):
    X = tf.placeholder(tf.float32, shape=[None, n_inputs], name="X")
    X_reshaped = tf.reshape(X, shape=[-1, height, width, channels])
    y = tf.placeholder(tf.int32, shape=[None], name="y")

with tf.name_scope("conv"):
    
    conv1 = tf.layers.conv2d(X_reshaped, filters=4, kernel_size=[3,3], strides=1, activation=tf.nn.relu, padding='SAME')
    conv2 = tf.layers.conv2d(conv1, filters=8, kernel_size=[3,3], strides=2, activation=tf.nn.relu, padding='SAME')

with tf.name_scope("pool3"):
    pool3 = tf.nn.max_pool(conv2, ksize=[1,2,2,1], strides=[1,1,1,1], padding='SAME')
    pool3_flat = tf.reshape(pool3, [-1, 7*7*32])

with tf.name_scope("fc1"):
    fc1 = tf.layers.dense(pool3_flat, units=16)

with tf.name_scope("fc2"):
    fc2 = tf.layers.dense(fc1, units=10)

with tf.name_scope("output"):
    logits = tf.layers.dense(fc2, units=4)
    Y_proba = tf.nn.softmax(logits)

with tf.name_scope("train"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer()
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_and_save"):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

# %% [markdown]
# ### Train 1459

# %%
n_epochs = 5
batch_size = 10

print("Training...")
with tf.Session() as sess:
    init.run()
    batched_dataset = dataset_1459_train.batch(batch_size)

    iterator = batched_dataset.make_initializable_iterator()
    next_batch = iterator.get_next()
    
    for epoch in range(n_epochs):
        sess.run(iterator.initializer)
        while True:
            try:
                X_batch, y_batch = sess.run(next_batch)
                sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
            except tf.errors.OutOfRangeError:
                # finished running through dataset
                break

        acc_train = accuracy.eval(feed_dict={X: X_1459_train, y: y_1459_train})
        acc_test = accuracy.eval(feed_dict={X: X_1459_test, y: y_1459_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        
    print("Finished training")

    print("Saving...")
    save_path = saver.save(sess, "./my_model_1459.ckpt")
        
    # for example
    inferred = sess.run(Y_proba, feed_dict={X: [X_1459_test[0]]})
    plot_image(X_1459_test[0].reshape(28,28), "Predicted %d, truth %d"%(np.argmax(inferred), y_1459_test[0]))
# Out:
# Training...
# 0 Train accuracy: 0.980435 Test accuracy: 0.983325
# 1 Train accuracy: 0.989921 Test accuracy: 0.992285
# 2 Train accuracy: 0.993022 Test accuracy: 0.993778
# 3 Train accuracy: 0.995211 Test accuracy: 0.994027
# 4 Train accuracy: 0.990696 Test accuracy: 0.990045
# Finished training
# Saving...

# %% [markdown]
# ### Build the graph for 023678

# %%
[n.name for n in tf.get_default_graph().as_graph_def().node]
# Out:
# [u'tensors/component_0',
#  u'tensors/component_1',
#  u'tensors_1/component_0',
#  u'tensors_1/component_1',
#  u'inputs/X',
#  u'inputs/Reshape/shape',
#  u'inputs/Reshape',
#  u'inputs/y',
#  u'conv2d/kernel/Initializer/random_uniform/shape',
#  u'conv2d/kernel/Initializer/random_uniform/min',
#  u'conv2d/kernel/Initializer/random_uniform/max',
#  u'conv2d/kernel/Initializer/random_uniform/RandomUniform',
#  u'conv2d/kernel/Initializer/random_uniform/sub',
#  u'conv2d/kernel/Initializer/random_uniform/mul',
#  u'conv2d/kernel/Initializer/random_uniform',
#  u'conv2d/kernel',
#  u'conv2d/kernel/Assign',
#  u'conv2d/kernel/read',
#  u'conv2d/bias/Initializer/zeros',
#  u'conv2d/bias',
#  u'conv2d/bias/Assign',
#  u'conv2d/bias/read',
#  u'conv/conv2d/dilation_rate',
#  u'conv/conv2d/Conv2D',
#  u'conv/conv2d/BiasAdd',
#  u'conv/conv2d/Relu',
#  u'conv2d_1/kernel/Initializer/random_uniform/shape',
#  u'conv2d_1/kernel/Initializer/random_uniform/min',
#  u'conv2d_1/kernel/Initializer/random_uniform/max',
#  u'conv2d_1/kernel/Initializer/random_uniform/RandomUniform',
#  u'conv2d_1/kernel/Initializer/random_uniform/sub',
#  u'conv2d_1/kernel/Initializer/random_uniform/mul',
#  u'conv2d_1/kernel/Initializer/random_uniform',
#  u'conv2d_1/kernel',
#  u'conv2d_1/kernel/Assign',
#  u'conv2d_1/kernel/read',
#  u'conv2d_1/bias/Initializer/zeros',
#  u'conv2d_1/bias',
#  u'conv2d_1/bias/Assign',
#  u'conv2d_1/bias/read',
#  u'conv/conv2d_2/dilation_rate',
#  u'conv/conv2d_2/Conv2D',
#  u'conv/conv2d_2/BiasAdd',
#  u'conv/conv2d_2/Relu',
#  u'pool3/MaxPool',
#  u'pool3/Reshape/shape',
#  u'pool3/Reshape',
#  u'dense/kernel/Initializer/random_uniform/shape',
#  u'dense/kernel/Initializer/random_uniform/min',
#  u'dense/kernel/Initializer/random_uniform/max',
#  u'dense/kernel/Initializer/random_uniform/RandomUniform',
#  u'dense/kernel/Initializer/random_uniform/sub',
#  u'dense/kernel/Initializer/random_uniform/mul',
#  u'dense/kernel/Initializer/random_uniform',
#  u'dense/kernel',
#  u'dense/kernel/Assign',
#  u'dense/kernel/read',
#  u'dense/bias/Initializer/zeros',
#  u'dense/bias',
#  u'dense/bias/Assign',
#  u'dense/bias/read',
#  u'fc1/dense/MatMul',
#  u'fc1/dense/BiasAdd',
#  u'dense_1/kernel/Initializer/random_uniform/shape',
#  u'dense_1/kernel/Initializer/random_uniform/min',
#  u'dense_1/kernel/Initializer/random_uniform/max',
#  u'dense_1/kernel/Initializer/random_uniform/RandomUniform',
#  u'dense_1/kernel/Initializer/random_uniform/sub',
#  u'dense_1/kernel/Initializer/random_uniform/mul',
#  u'dense_1/kernel/Initializer/random_uniform',
#  u'dense_1/kernel',
#  u'dense_1/kernel/Assign',
#  u'dense_1/kernel/read',
#  u'dense_1/bias/Initializer/zeros',
#  u'dense_1/bias',
#  u'dense_1/bias/Assign',
#  u'dense_1/bias/read',
#  u'fc2/dense/MatMul',
#  u'fc2/dense/BiasAdd',
#  u'dense_2/kernel/Initializer/random_uniform/shape',
#  u'dense_2/kernel/Initializer/random_uniform/min',
#  u'dense_2/kernel/Initializer/random_uniform/max',
#  u'dense_2/kernel/Initializer/random_uniform/RandomUniform',
#  u'dense_2/kernel/Initializer/random_uniform/sub',
#  u'dense_2/kernel/Initializer/random_uniform/mul',
#  u'dense_2/kernel/Initializer/random_uniform',
#  u'dense_2/kernel',
#  u'dense_2/kernel/Assign',
#  u'dense_2/kernel/read',
#  u'dense_2/bias/Initializer/zeros',
#  u'dense_2/bias',
#  u'dense_2/bias/Assign',
#  u'dense_2/bias/read',
#  u'output/dense/MatMul',
#  u'output/dense/BiasAdd',
#  u'output/Softmax',
#  u'train/SparseSoftmaxCrossEntropyWithLogits/Shape',
#  u'train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits',
#  u'train/Const',
#  u'train/Mean',
#  u'train/gradients/Shape',
#  u'train/gradients/Const',
#  u'train/gradients/Fill',
#  u'train/gradients/train/Mean_grad/Reshape/shape',
#  u'train/gradients/train/Mean_grad/Reshape',
#  u'train/gradients/train/Mean_grad/Shape',
#  u'train/gradients/train/Mean_grad/Tile',
#  u'train/gradients/train/Mean_grad/Shape_1',
#  u'train/gradients/train/Mean_grad/Shape_2',
#  u'train/gradients/train/Mean_grad/Const',
#  u'train/gradients/train/Mean_grad/Prod',
#  u'train/gradients/train/Mean_grad/Const_1',
#  u'train/gradients/train/Mean_grad/Prod_1',
#  u'train/gradients/train/Mean_grad/Maximum/y',
#  u'train/gradients/train/Mean_grad/Maximum',
#  u'train/gradients/train/Mean_grad/floordiv',
#  u'train/gradients/train/Mean_grad/Cast',
#  u'train/gradients/train/Mean_grad/truediv',
#  u'train/gradients/zeros_like',
#  u'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient',
#  u'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  u'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  u'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul',
#  u'train/gradients/output/dense/BiasAdd_grad/BiasAddGrad',
#  u'train/gradients/output/dense/BiasAdd_grad/tuple/group_deps',
#  u'train/gradients/output/dense/BiasAdd_grad/tuple/control_dependency',
#  u'train/gradients/output/dense/BiasAdd_grad/tuple/control_dependency_1',
#  u'train/gradients/output/dense/MatMul_grad/MatMul',
#  u'train/gradients/output/dense/MatMul_grad/MatMul_1',
#  u'train/gradients/output/dense/MatMul_grad/tuple/group_deps',
#  u'train/gradients/output/dense/MatMul_grad/tuple/control_dependency',
#  u'train/gradients/output/dense/MatMul_grad/tuple/control_dependency_1',
#  u'train/gradients/fc2/dense/BiasAdd_grad/BiasAddGrad',
#  u'train/gradients/fc2/dense/BiasAdd_grad/tuple/group_deps',
#  u'train/gradients/fc2/dense/BiasAdd_grad/tuple/control_dependency',
#  u'train/gradients/fc2/dense/BiasAdd_grad/tuple/control_dependency_1',
#  u'train/gradients/fc2/dense/MatMul_grad/MatMul',
#  u'train/gradients/fc2/dense/MatMul_grad/MatMul_1',
#  u'train/gradients/fc2/dense/MatMul_grad/tuple/group_deps',
#  u'train/gradients/fc2/dense/MatMul_grad/tuple/control_dependency',
#  u'train/gradients/fc2/dense/MatMul_grad/tuple/control_dependency_1',
#  u'train/gradients/fc1/dense/BiasAdd_grad/BiasAddGrad',
#  u'train/gradients/fc1/dense/BiasAdd_grad/tuple/group_deps',
#  u'train/gradients/fc1/dense/BiasAdd_grad/tuple/control_dependency',
#  u'train/gradients/fc1/dense/BiasAdd_grad/tuple/control_dependency_1',
#  u'train/gradients/fc1/dense/MatMul_grad/MatMul',
#  u'train/gradients/fc1/dense/MatMul_grad/MatMul_1',
#  u'train/gradients/fc1/dense/MatMul_grad/tuple/group_deps',
#  u'train/gradients/fc1/dense/MatMul_grad/tuple/control_dependency',
#  u'train/gradients/fc1/dense/MatMul_grad/tuple/control_dependency_1',
#  u'train/gradients/pool3/Reshape_grad/Shape',
#  u'train/gradients/pool3/Reshape_grad/Reshape',
#  u'train/gradients/pool3/MaxPool_grad/MaxPoolGrad',
#  u'train/gradients/conv/conv2d_2/Relu_grad/ReluGrad',
#  u'train/gradients/conv/conv2d_2/BiasAdd_grad/BiasAddGrad',
#  u'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/group_deps',
#  u'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency',
#  u'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency_1',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/ShapeN',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropInput',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropFilter',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/group_deps',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency',
#  u'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency_1',
#  u'train/gradients/conv/conv2d/Relu_grad/ReluGrad',
#  u'train/gradients/conv/conv2d/BiasAdd_grad/BiasAddGrad',
#  u'train/gradients/conv/conv2d/BiasAdd_grad/tuple/group_deps',
#  u'train/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency',
#  u'train/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  u'train/gradients/conv/conv2d/Conv2D_grad/ShapeN',
#  u'train/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  u'train/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  u'train/gradients/conv/conv2d/Conv2D_grad/tuple/group_deps',
#  u'train/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency',
#  u'train/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  u'train/beta1_power/initial_value',
#  u'train/beta1_power',
#  u'train/beta1_power/Assign',
#  u'train/beta1_power/read',
#  u'train/beta2_power/initial_value',
#  u'train/beta2_power',
#  u'train/beta2_power/Assign',
#  u'train/beta2_power/read',
#  u'conv2d/kernel/Adam/Initializer/zeros',
#  u'conv2d/kernel/Adam',
#  u'conv2d/kernel/Adam/Assign',
#  u'conv2d/kernel/Adam/read',
#  u'conv2d/kernel/Adam_1/Initializer/zeros',
#  u'conv2d/kernel/Adam_1',
#  u'conv2d/kernel/Adam_1/Assign',
#  u'conv2d/kernel/Adam_1/read',
#  u'conv2d/bias/Adam/Initializer/zeros',
#  u'conv2d/bias/Adam',
#  u'conv2d/bias/Adam/Assign',
#  u'conv2d/bias/Adam/read',
#  u'conv2d/bias/Adam_1/Initializer/zeros',
#  u'conv2d/bias/Adam_1',
#  u'conv2d/bias/Adam_1/Assign',
#  u'conv2d/bias/Adam_1/read',
#  u'conv2d_1/kernel/Adam/Initializer/zeros',
#  u'conv2d_1/kernel/Adam',
#  u'conv2d_1/kernel/Adam/Assign',
#  u'conv2d_1/kernel/Adam/read',
#  u'conv2d_1/kernel/Adam_1/Initializer/zeros',
#  u'conv2d_1/kernel/Adam_1',
#  u'conv2d_1/kernel/Adam_1/Assign',
#  u'conv2d_1/kernel/Adam_1/read',
#  u'conv2d_1/bias/Adam/Initializer/zeros',
#  u'conv2d_1/bias/Adam',
#  u'conv2d_1/bias/Adam/Assign',
#  u'conv2d_1/bias/Adam/read',
#  u'conv2d_1/bias/Adam_1/Initializer/zeros',
#  u'conv2d_1/bias/Adam_1',
#  u'conv2d_1/bias/Adam_1/Assign',
#  u'conv2d_1/bias/Adam_1/read',
#  u'dense/kernel/Adam/Initializer/zeros',
#  u'dense/kernel/Adam',
#  u'dense/kernel/Adam/Assign',
#  u'dense/kernel/Adam/read',
#  u'dense/kernel/Adam_1/Initializer/zeros',
#  u'dense/kernel/Adam_1',
#  u'dense/kernel/Adam_1/Assign',
#  u'dense/kernel/Adam_1/read',
#  u'dense/bias/Adam/Initializer/zeros',
#  u'dense/bias/Adam',
#  u'dense/bias/Adam/Assign',
#  u'dense/bias/Adam/read',
#  u'dense/bias/Adam_1/Initializer/zeros',
#  u'dense/bias/Adam_1',
#  u'dense/bias/Adam_1/Assign',
#  u'dense/bias/Adam_1/read',
#  u'dense_1/kernel/Adam/Initializer/zeros',
#  u'dense_1/kernel/Adam',
#  u'dense_1/kernel/Adam/Assign',
#  u'dense_1/kernel/Adam/read',
#  u'dense_1/kernel/Adam_1/Initializer/zeros',
#  u'dense_1/kernel/Adam_1',
#  u'dense_1/kernel/Adam_1/Assign',
#  u'dense_1/kernel/Adam_1/read',
#  u'dense_1/bias/Adam/Initializer/zeros',
#  u'dense_1/bias/Adam',
#  u'dense_1/bias/Adam/Assign',
#  u'dense_1/bias/Adam/read',
#  u'dense_1/bias/Adam_1/Initializer/zeros',
#  u'dense_1/bias/Adam_1',
#  u'dense_1/bias/Adam_1/Assign',
#  u'dense_1/bias/Adam_1/read',
#  u'dense_2/kernel/Adam/Initializer/zeros',
#  u'dense_2/kernel/Adam',
#  u'dense_2/kernel/Adam/Assign',
#  u'dense_2/kernel/Adam/read',
#  u'dense_2/kernel/Adam_1/Initializer/zeros',
#  u'dense_2/kernel/Adam_1',
#  u'dense_2/kernel/Adam_1/Assign',
#  u'dense_2/kernel/Adam_1/read',
#  u'dense_2/bias/Adam/Initializer/zeros',
#  u'dense_2/bias/Adam',
#  u'dense_2/bias/Adam/Assign',
#  u'dense_2/bias/Adam/read',
#  u'dense_2/bias/Adam_1/Initializer/zeros',
#  u'dense_2/bias/Adam_1',
#  u'dense_2/bias/Adam_1/Assign',
#  u'dense_2/bias/Adam_1/read',
#  u'train/Adam/learning_rate',
#  u'train/Adam/beta1',
#  u'train/Adam/beta2',
#  u'train/Adam/epsilon',
#  u'train/Adam/update_conv2d/kernel/ApplyAdam',
#  u'train/Adam/update_conv2d/bias/ApplyAdam',
#  u'train/Adam/update_conv2d_1/kernel/ApplyAdam',
#  u'train/Adam/update_conv2d_1/bias/ApplyAdam',
#  u'train/Adam/update_dense/kernel/ApplyAdam',
#  u'train/Adam/update_dense/bias/ApplyAdam',
#  u'train/Adam/update_dense_1/kernel/ApplyAdam',
#  u'train/Adam/update_dense_1/bias/ApplyAdam',
#  u'train/Adam/update_dense_2/kernel/ApplyAdam',
#  u'train/Adam/update_dense_2/bias/ApplyAdam',
#  u'train/Adam/mul',
#  u'train/Adam/Assign',
#  u'train/Adam/mul_1',
#  u'train/Adam/Assign_1',
#  u'train/Adam',
#  u'eval/in_top_k/InTopKV2/k',
#  u'eval/in_top_k/InTopKV2',
#  u'eval/Cast',
#  u'eval/Const',
#  u'eval/Mean',
#  u'init_and_save/init',
#  u'init_and_save/save/Const',
#  u'init_and_save/save/SaveV2/tensor_names',
#  u'init_and_save/save/SaveV2/shape_and_slices',
#  u'init_and_save/save/SaveV2',
#  u'init_and_save/save/control_dependency',
#  u'init_and_save/save/RestoreV2/tensor_names',
#  u'init_and_save/save/RestoreV2/shape_and_slices',
#  u'init_and_save/save/RestoreV2',
#  u'init_and_save/save/Assign',
#  u'init_and_save/save/RestoreV2_1/tensor_names',
#  u'init_and_save/save/RestoreV2_1/shape_and_slices',
#  u'init_and_save/save/RestoreV2_1',
#  u'init_and_save/save/Assign_1',
#  u'init_and_save/save/RestoreV2_2/tensor_names',
#  u'init_and_save/save/RestoreV2_2/shape_and_slices',
#  u'init_and_save/save/RestoreV2_2',
#  u'init_and_save/save/Assign_2',
#  u'init_and_save/save/RestoreV2_3/tensor_names',
#  u'init_and_save/save/RestoreV2_3/shape_and_slices',
#  u'init_and_save/save/RestoreV2_3',
#  u'init_and_save/save/Assign_3',
#  u'init_and_save/save/RestoreV2_4/tensor_names',
#  u'init_and_save/save/RestoreV2_4/shape_and_slices',
#  u'init_and_save/save/RestoreV2_4',
#  u'init_and_save/save/Assign_4',
#  u'init_and_save/save/RestoreV2_5/tensor_names',
#  u'init_and_save/save/RestoreV2_5/shape_and_slices',
#  u'init_and_save/save/RestoreV2_5',
#  u'init_and_save/save/Assign_5',
#  u'init_and_save/save/RestoreV2_6/tensor_names',
#  u'init_and_save/save/RestoreV2_6/shape_and_slices',
#  u'init_and_save/save/RestoreV2_6',
#  u'init_and_save/save/Assign_6',
#  u'init_and_save/save/RestoreV2_7/tensor_names',
#  u'init_and_save/save/RestoreV2_7/shape_and_slices',
#  u'init_and_save/save/RestoreV2_7',
#  u'init_and_save/save/Assign_7',
#  u'init_and_save/save/RestoreV2_8/tensor_names',
#  u'init_and_save/save/RestoreV2_8/shape_and_slices',
#  u'init_and_save/save/RestoreV2_8',
#  u'init_and_save/save/Assign_8',
#  u'init_and_save/save/RestoreV2_9/tensor_names',
#  u'init_and_save/save/RestoreV2_9/shape_and_slices',
#  u'init_and_save/save/RestoreV2_9',
#  u'init_and_save/save/Assign_9',
#  u'init_and_save/save/RestoreV2_10/tensor_names',
#  u'init_and_save/save/RestoreV2_10/shape_and_slices',
#  u'init_and_save/save/RestoreV2_10',
#  u'init_and_save/save/Assign_10',
#  u'init_and_save/save/RestoreV2_11/tensor_names',
#  u'init_and_save/save/RestoreV2_11/shape_and_slices',
#  u'init_and_save/save/RestoreV2_11',
#  u'init_and_save/save/Assign_11',
#  u'init_and_save/save/RestoreV2_12/tensor_names',
#  u'init_and_save/save/RestoreV2_12/shape_and_slices',
#  u'init_and_save/save/RestoreV2_12',
#  u'init_and_save/save/Assign_12',
#  u'init_and_save/save/RestoreV2_13/tensor_names',
#  u'init_and_save/save/RestoreV2_13/shape_and_slices',
#  u'init_and_save/save/RestoreV2_13',
#  u'init_and_save/save/Assign_13',
#  u'init_and_save/save/RestoreV2_14/tensor_names',
#  u'init_and_save/save/RestoreV2_14/shape_and_slices',
#  u'init_and_save/save/RestoreV2_14',
#  u'init_and_save/save/Assign_14',
#  u'init_and_save/save/RestoreV2_15/tensor_names',
#  u'init_and_save/save/RestoreV2_15/shape_and_slices',
#  u'init_and_save/save/RestoreV2_15',
#  u'init_and_save/save/Assign_15',
#  u'init_and_save/save/RestoreV2_16/tensor_names',
#  u'init_and_save/save/RestoreV2_16/shape_and_slices',
#  u'init_and_save/save/RestoreV2_16',
#  u'init_and_save/save/Assign_16',
#  u'init_and_save/save/RestoreV2_17/tensor_names',
#  u'init_and_save/save/RestoreV2_17/shape_and_slices',
#  u'init_and_save/save/RestoreV2_17',
#  u'init_and_save/save/Assign_17',
#  u'init_and_save/save/RestoreV2_18/tensor_names',
#  u'init_and_save/save/RestoreV2_18/shape_and_slices',
#  u'init_and_save/save/RestoreV2_18',
#  u'init_and_save/save/Assign_18',
#  u'init_and_save/save/RestoreV2_19/tensor_names',
#  u'init_and_save/save/RestoreV2_19/shape_and_slices',
#  u'init_and_save/save/RestoreV2_19',
#  u'init_and_save/save/Assign_19',
#  u'init_and_save/save/RestoreV2_20/tensor_names',
#  u'init_and_save/save/RestoreV2_20/shape_and_slices',
#  u'init_and_save/save/RestoreV2_20',
#  u'init_and_save/save/Assign_20',
#  u'init_and_save/save/RestoreV2_21/tensor_names',
#  u'init_and_save/save/RestoreV2_21/shape_and_slices',
#  u'init_and_save/save/RestoreV2_21',
#  u'init_and_save/save/Assign_21',
#  u'init_and_save/save/RestoreV2_22/tensor_names',
#  u'init_and_save/save/RestoreV2_22/shape_and_slices',
#  u'init_and_save/save/RestoreV2_22',
#  u'init_and_save/save/Assign_22',
#  u'init_and_save/save/RestoreV2_23/tensor_names',
#  u'init_and_save/save/RestoreV2_23/shape_and_slices',
#  u'init_and_save/save/RestoreV2_23',
#  u'init_and_save/save/Assign_23',
#  u'init_and_save/save/RestoreV2_24/tensor_names',
#  u'init_and_save/save/RestoreV2_24/shape_and_slices',
#  u'init_and_save/save/RestoreV2_24',
#  u'init_and_save/save/Assign_24',
#  u'init_and_save/save/RestoreV2_25/tensor_names',
#  u'init_and_save/save/RestoreV2_25/shape_and_slices',
#  u'init_and_save/save/RestoreV2_25',
#  u'init_and_save/save/Assign_25',
#  u'init_and_save/save/RestoreV2_26/tensor_names',
#  u'init_and_save/save/RestoreV2_26/shape_and_slices',
#  u'init_and_save/save/RestoreV2_26',
#  u'init_and_save/save/Assign_26',
#  u'init_and_save/save/RestoreV2_27/tensor_names',
#  u'init_and_save/save/RestoreV2_27/shape_and_slices',
#  u'init_and_save/save/RestoreV2_27',
#  u'init_and_save/save/Assign_27',
#  u'init_and_save/save/RestoreV2_28/tensor_names',
#  u'init_and_save/save/RestoreV2_28/shape_and_slices',
#  u'init_and_save/save/RestoreV2_28',
#  u'init_and_save/save/Assign_28',
#  u'init_and_save/save/RestoreV2_29/tensor_names',
#  u'init_and_save/save/RestoreV2_29/shape_and_slices',
#  u'init_and_save/save/RestoreV2_29',
#  u'init_and_save/save/Assign_29',
#  u'init_and_save/save/RestoreV2_30/tensor_names',
#  u'init_and_save/save/RestoreV2_30/shape_and_slices',
#  u'init_and_save/save/RestoreV2_30',
#  u'init_and_save/save/Assign_30',
#  u'init_and_save/save/RestoreV2_31/tensor_names',
#  u'init_and_save/save/RestoreV2_31/shape_and_slices',
#  u'init_and_save/save/RestoreV2_31',
#  u'init_and_save/save/Assign_31',
#  u'init_and_save/save/restore_all',
#  u'Iterator',
#  u'TensorSliceDataset',
#  u'BatchDataset/batch_size',
#  u'BatchDataset',
#  u'MakeIterator',
#  u'IteratorGetNext']

# %%
reset_graph()
prepare_data()

# restore the graph of 1459
restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")

# reuse the inputs (X,y)
X = tf.get_default_graph().get_tensor_by_name("inputs/X:0")
y = tf.get_default_graph().get_tensor_by_name("inputs/y:0")
# reuse the FC1 layer
fc1 = tf.get_default_graph().get_tensor_by_name("fc1/dense/MatMul:0")
# reuse the FC2 layer
fc2_reuse = tf.get_default_graph().get_tensor_by_name("fc2/dense/MatMul:0")

# continue the 023678 graph from FC2...
with tf.name_scope("fc2_023678"):
    fc2 = tf.layers.dense(fc1, units=10, name="fc2_023678")

with tf.name_scope("softmax_023678"):
    logits = tf.layers.dense(fc2, units=6, name="output_023678")
    Y_proba = tf.nn.softmax(logits, name="Y_proba_023678")

with tf.name_scope("train_023678"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer(name="adam_023678")
## try to freeze everything but fc2, softmax
#     train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="fc2_023678|softmax_023678")
#     training_op = optimizer.minimize(loss, var_list=train_vars)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval_023678"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_023678"):
    init = tf.global_variables_initializer()
    new_saver = tf.train.Saver()

# %% [markdown]
# ## Train transferred 023678

# %%
n_epochs = 3
batch_size = 10

print("Training 023678...")
with tf.Session() as sess:
    init.run()
    batched_dataset = dataset_023678_train.batch(batch_size)

    iterator = batched_dataset.make_initializable_iterator()
    next_batch = iterator.get_next()
    
    saver.restore(sess, "./my_model_1459.ckpt")
    
    for epoch in range(n_epochs):
        sess.run(iterator.initializer)
        while True:
            try:
                X_batch, y_batch = sess.run(next_batch)
                sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
            except tf.errors.OutOfRangeError:
                # finished running through dataset
                break

        acc_train = accuracy.eval(feed_dict={X: X_023678_train, y: y_023678_train})
        acc_test = accuracy.eval(feed_dict={X: X_023678_test, y: y_023678_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        
    print("Finished training")

    # for example
    inferred = sess.run(Y_proba, feed_dict={X: [X_023678_test[0]]})
    plot_image(X_023678_test[0].reshape(28,28), "Predicted %d, truth %d"%(np.argmax(inferred), y_023678_test[0]))
# Out:
# Training 023678...
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt
# 0 Train accuracy: 0.981677 Test accuracy: 0.980608
# 1 Train accuracy: 0.982917 Test accuracy: 0.980608
# 2 Train accuracy: 0.986515 Test accuracy: 0.981946
# 3 Train accuracy: 0.991534 Test accuracy: 0.985122
# 4 Train accuracy: 0.993378 Test accuracy: 0.986292
# 5 Train accuracy: 0.994255 Test accuracy: 0.986292
# 6 Train accuracy: 0.993983 Test accuracy: 0.986292
# 7 Train accuracy: 0.994225 Test accuracy: 0.986125
# 8 Train accuracy: 0.99622 Test accuracy: 0.986627
# 9 Train accuracy: 0.996251 Test accuracy: 0.984955
# 10 Train accuracy: 0.996644 Test accuracy: 0.985624
# 11 Train accuracy: 0.997158 Test accuracy: 0.98763
# 12 Train accuracy: 0.996734 Test accuracy: 0.986292
# 13 Train accuracy: 0.996583 Test accuracy: 0.986627
# 14 Train accuracy: 0.996704 Test accuracy: 0.986459
# 15 Train accuracy: 0.997581 Test accuracy: 0.986459
# 16 Train accuracy: 0.995374 Test accuracy: 0.985958
# 17 Train accuracy: 0.995797 Test accuracy: 0.984453
# 18 Train accuracy: 0.996432 Test accuracy: 0.986627
# 19 Train accuracy: 0.996976 Test accuracy: 0.986794
# Finished training

# %% [markdown]
# ## Visualize the Feature Maps
# The following code is useful to look into the activations of convolutional and pooling layers

# %%
import math

with tf.Session() as sess:

    saver.restore(sess, "./my_model_1459.ckpt")
    # getActivations(tf.get_default_graph().get_tensor_by_name(...), X_1459_test[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt

# %% [markdown]
# ### Visualize the convolution kernels

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_1459.ckpt")
    
    # plotConvLayerWeights(...)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt

# %% [markdown]
# ## Show the Execution Graph

# %%
reset_graph()

# restore the graph of 1459
restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")

show_graph(tf.get_default_graph())
