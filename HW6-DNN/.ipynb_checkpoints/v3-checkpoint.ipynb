# %% [markdown]
# ## Setup

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12


# Code to visualize the execution graph in the jupyter notebook
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = b"<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
import tensorflow as tf

# %%
def plot_image(image,title=None):
    plt.figure()
    plt.imshow(image, cmap="gray", interpolation="nearest")
    if title is not None:
        plt.title(title)
    plt.axis("off")

def plot_color_image(image):
    plt.imshow(image.astype(np.uint8),interpolation="nearest")
    plt.axis("off")
    
def getActivations(layer,stimuli):
    units = sess.run(layer,feed_dict={X:np.reshape(stimuli,[1,784],order='F')})
    plotNNFilter(units)

# visualize convolution activations
def plotNNFilter(units):
    filters = units.shape[3]
    plt.figure(1, figsize=(20,20))
    n_columns = 6
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.imshow(units[0,:,:,i], interpolation="nearest", cmap="gray")

# visualize convolution kernels
def plotConvLayerWeights(conv_layer_name, sess):
    kernel = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, conv_layer_name)[0]
    weights = sess.run(kernel)
    print(kernel.shape)
    
    n_filters = int(kernel.shape[3])
    n_base_layers = int(kernel.shape[2])
    plt.figure(figsize=(20,20))
    for j in range(n_base_layers):
        for i in range(n_filters):
            plt.subplot(n_base_layers, n_filters, j * n_filters + i + 1)
            plt.xticks([])
            plt.yticks([])
            plt.imshow(weights[:,:,j,i].reshape(kernel.shape[0],kernel.shape[1]), cmap='gray', interpolation='nearest')
            plt.title(str(i+1))

# %% [markdown]
# ## Load MNIST

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ### Select 1459 and 023678 from MNIST

# %%
def prepare_data():
    global  dataset_1459_train, \
            dataset_023678_train, \
            X_1459_train, \
            y_1459_train, \
            X_1459_test, \
            y_1459_test, \
            X_023678_test, \
            y_023678_test, \
            X_023678_train, \
            y_023678_train
    mask_1459_train = np.logical_or.reduce([mnist.train.labels == v for v in [1,4,5,9]])
    mask_1459_test  = np.logical_or.reduce([mnist.test.labels  == v for v in [1,4,5,9]])
    X_1459_train = np.compress(np.array(mask_1459_train), mnist.train.images, axis=0)
    _, y_1459_train = np.unique(mnist.train.labels[mask_1459_train], return_inverse=True) # 1,4,5,9 to 0,1,2,3
    dataset_1459_train = tf.contrib.data.Dataset.from_tensor_slices((X_1459_train,y_1459_train))

    X_1459_test = np.compress(np.array(mask_1459_test), mnist.test.images, axis=0)
    _, y_1459_test = np.unique(mnist.test.labels[mask_1459_test], return_inverse=True)

    mask_023678_train = np.logical_or.reduce([mnist.train.labels == v for v in [0,2,3,6,7,8]])
    mask_023678_test  = np.logical_or.reduce([mnist.test.labels  == v for v in [0,2,3,6,7,8]])
    X_023678_train = np.compress(np.array(mask_023678_train), mnist.train.images, axis=0)
    _, y_023678_train = np.unique(mnist.train.labels[mask_023678_train], return_inverse=True) # 1,4,5,9 to 0,1,2,3
    dataset_023678_train = tf.contrib.data.Dataset.from_tensor_slices((X_023678_train,y_023678_train))

    X_023678_test = np.compress(np.array(mask_023678_test), mnist.test.images, axis=0)
    _, y_023678_test = np.unique(mnist.test.labels[mask_023678_test], return_inverse=True)

prepare_data()

# for example
plot_image(X_1459_test[2].reshape(28,28),title=y_1459_test[2])
plot_image(X_023678_test[2].reshape(28,28),title=y_023678_test[2])
# Out:
# WARNING:tensorflow:From <ipython-input-5-c9cee9b3a086>:7: Dataset.from_tensor_slices (from tensorflow.contrib.data.python.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.from_tensor_slices()`.

# %% [markdown]
# # Convolutional Network

# %% [markdown]
# ### Construct Graph

# %%
height = 28
width = 28
channels = 1
n_inputs = height * width
n_outputs = 4


reset_graph()
prepare_data()

# inputs layer
with tf.name_scope("inputs"):
    X = tf.placeholder(tf.float32, shape=[None, n_inputs], name="X")
    X_reshaped = tf.reshape(X, shape=[-1, height, width, channels])
    y = tf.placeholder(tf.int32, shape=[None], name="y")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    

with tf.name_scope("conv"):
    conv1 = tf.layers.conv2d(inputs=X_reshaped, filters=4, kernel_size=[5, 5], strides=(1, 1), padding="SAME", activation=tf.nn.relu)
    #dropout = tf.layers.dropout(inputs=conv1, rate=0.2, training=mode == tf.estimator.ModeKeys.TRAIN)
    dropout1 = tf.nn.dropout(conv1, keep_prob)
    
    conv2 = tf.layers.conv2d(dropout1, filters=16, kernel_size=[5, 5], strides=1, padding="SAME", activation=tf.nn.relu)
    dropout2 = tf.nn.dropout(conv2, keep_prob)

with tf.name_scope("pool3"):
    pool3 = tf.nn.max_pool(dropout2, [1, 2, 2, 1], [1, 1, 1, 1], "SAME")
    pool3_flat = tf.reshape(pool3, [-1, 14 * 14 * 64])

with tf.name_scope("fc1"):
    fc1 = tf.layers.dense(pool3_flat, 16, name="fc1", activation=tf.nn.relu)
    dropout3 = tf.nn.dropout(fc1, keep_prob)

with tf.name_scope("fc2"):
    fc2 = tf.layers.dense(dropout3, 10, name="fc2", activation=tf.nn.relu)

with tf.name_scope("output"):
    logits = tf.layers.dense(fc2, 4)
    Y_proba = tf.nn.softmax(logits)

with tf.name_scope("train"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer()
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_and_save"):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

# %% [markdown]
# ### Train 1459

# %%
n_epochs = 5
batch_size = 10

print("Training...")
with tf.Session() as sess:
    init.run()
    batched_dataset = dataset_1459_train.batch(batch_size)

    iterator = batched_dataset.make_initializable_iterator()
    next_batch = iterator.get_next()
    
    for epoch in range(n_epochs):
        sess.run(iterator.initializer)
        while True:
            try:
                X_batch, y_batch = sess.run(next_batch)
                sess.run(training_op, feed_dict={X: X_batch, y: y_batch, keep_prob: 0.8})
            except tf.errors.OutOfRangeError:
                # finished running through dataset
                break

        acc_train = accuracy.eval(feed_dict={X: X_1459_train, y: y_1459_train, keep_prob: 1.0})
        acc_test = accuracy.eval(feed_dict={X: X_1459_test, y: y_1459_test, keep_prob: 1.0})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        
    print("Finished training")

    print("Saving...")
    save_path = saver.save(sess, "./my_model_1459.ckpt")
        
    # for example
    inferred = sess.run(Y_proba, feed_dict={X: [X_1459_test[0]],keep_prob: 1.0})
    plot_image(X_1459_test[0].reshape(28,28), "Predicted %d, truth %d"%(np.argmax(inferred), y_1459_test[0]))
# Out:
# Training...
# 0 Train accuracy: 0.99398 Test accuracy: 0.992285
# 1 Train accuracy: 0.995348 Test accuracy: 0.994774
# 2 Train accuracy: 0.989419 Test accuracy: 0.987556
# 3 Train accuracy: 0.997172 Test accuracy: 0.994027
# 4 Train accuracy: 0.996625 Test accuracy: 0.990791
# Finished training
# Saving...

# %% [markdown]
# ### Build the graph for 023678

# %% [markdown]
# ## Train transferred 023678

# %%
reset_graph()
prepare_data()

# restore the graph of 1459
restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")
#keep_prob = tf.placeholder(tf.float32)

# reuse the inputs (X,y)
X = tf.get_default_graph().get_tensor_by_name("inputs/X:0")
y = tf.get_default_graph().get_tensor_by_name("inputs/y:0")
keep_prob = tf.get_default_graph().get_tensor_by_name("inputs/keep_prob:0")
# reuse the FC1 layer
fc1 = tf.get_default_graph().get_tensor_by_name("fc1/fc1/Relu:0")
# reuse the FC2 layer
fc2_reuse = tf.get_default_graph().get_tensor_by_name("fc2/fc2/Relu:0")


# continue the 023678 graph from FC2...
with tf.name_scope("fc2_023678"):
    fc2 = tf.layers.dense(fc2_reuse, 16, name="fc2_023678")
    
#dropout = tf.nn.dropout(fc2, keep_prob)
    
with tf.name_scope("softmax_023678"):
    # logits = tf.layers.dense(fc2, ..., name="output_023678")
    logits = tf.layers.dense(fc2, 6, name="output_023678")
    Y_proba = tf.nn.softmax(logits, name="Y_proba_023678")

with tf.name_scope("train_023678"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer(name="adam_023678")
## try to freeze everything but fc2, softmax
#     train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="fc2_023678|softmax_023678")
#     training_op = optimizer.minimize(loss, var_list=train_vars)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval_023678"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_023678"):
    init = tf.global_variables_initializer()
    new_saver = tf.train.Saver()
    
#--------------------------------------------   

n_epochs = 5
batch_size = 10

print("Training 023678...")
with tf.Session() as sess:
    init.run()
    batched_dataset = dataset_023678_train.batch(batch_size)

    iterator = batched_dataset.make_initializable_iterator()
    next_batch = iterator.get_next()
    
    saver.restore(sess, "./my_model_1459.ckpt")
    
    for epoch in range(n_epochs):
        sess.run(iterator.initializer)
        while True:
            try:
                X_batch, y_batch = sess.run(next_batch)
                sess.run(training_op, feed_dict={X: X_batch, y: y_batch, keep_prob: 1.0})
            except tf.errors.OutOfRangeError:
                # finished running through dataset
                break

        acc_train = accuracy.eval(feed_dict={X: X_023678_train, y: y_023678_train, keep_prob: 1.0})
        acc_test = accuracy.eval(feed_dict={X: X_023678_test, y: y_023678_test, keep_prob: 1.0})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        
    print("Finished training")

    # for example
    inferred = sess.run(Y_proba, feed_dict={X: [X_023678_test[0]], keep_prob: 1.0})
    plot_image(X_023678_test[0].reshape(28,28), "Predicted %d, truth %d"%(np.argmax(inferred), y_023678_test[0]))
# Out:
# Training 023678...
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt
# 0 Train accuracy: 0.986817 Test accuracy: 0.986459
# 1 Train accuracy: 0.991232 Test accuracy: 0.989636
# 2 Train accuracy: 0.993469 Test accuracy: 0.990137
# 3 Train accuracy: 0.994769 Test accuracy: 0.991307
# 4 Train accuracy: 0.993741 Test accuracy: 0.989636
# Finished training

# %% [markdown]
# # Freezing layers

# %%
reset_graph()
prepare_data()

# restore the graph of 1459
restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")
#keep_prob = tf.placeholder(tf.float32)

# reuse the inputs (X,y)
X = tf.get_default_graph().get_tensor_by_name("inputs/X:0")
y = tf.get_default_graph().get_tensor_by_name("inputs/y:0")
keep_prob = tf.get_default_graph().get_tensor_by_name("inputs/keep_prob:0")
# reuse the FC1 layer
fc1 = tf.get_default_graph().get_tensor_by_name("fc1/fc1/Relu:0")
# reuse the FC2 layer
fc2_reuse = tf.get_default_graph().get_tensor_by_name("fc2/fc2/Relu:0")


# continue the 023678 graph from FC2...
with tf.name_scope("fc2_023678"):
    fc2 = tf.layers.dense(fc2_reuse, 16, name="fc2_023678")
    
#dropout = tf.nn.dropout(fc2, keep_prob)
    
with tf.name_scope("softmax_023678"):
    # logits = tf.layers.dense(fc2, ..., name="output_023678")
    logits = tf.layers.dense(fc2, 6, name="output_023678")
    Y_proba = tf.nn.softmax(logits, name="Y_proba_023678")

with tf.name_scope("train_023678"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer(name="adam_023678")
## try to freeze everything but fc2, softmax
    train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="fc2_023678|softmax_023678")
    training_op = optimizer.minimize(loss, var_list=train_vars)
#    training_op = optimizer.minimize(loss)

with tf.name_scope("eval_023678"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_023678"):
    init = tf.global_variables_initializer()
    new_saver = tf.train.Saver()

# %%
n_epochs = 5
batch_size = 10

print("Training 023678...")
with tf.Session() as sess:
    init.run()
    batched_dataset = dataset_023678_train.batch(batch_size)

    iterator = batched_dataset.make_initializable_iterator()
    next_batch = iterator.get_next()
    
    saver.restore(sess, "./my_model_1459.ckpt")
    
    for epoch in range(n_epochs):
        sess.run(iterator.initializer)
        while True:
            try:
                X_batch, y_batch = sess.run(next_batch)
                sess.run(training_op, feed_dict={X: X_batch, y: y_batch, keep_prob: 0.8})
            except tf.errors.OutOfRangeError:
                # finished running through dataset
                break

        acc_train = accuracy.eval(feed_dict={X: X_023678_train, y: y_023678_train, keep_prob: 1.0})
        acc_test = accuracy.eval(feed_dict={X: X_023678_test, y: y_023678_test, keep_prob: 1.0})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        
    print("Finished training")

    # for example
    inferred = sess.run(Y_proba, feed_dict={X: [X_023678_test[0]], keep_prob: 1.0})
    plot_image(X_023678_test[0].reshape(28,28), "Predicted %d, truth %d"%(np.argmax(inferred), y_023678_test[0]))
# Out:
# Training 023678...
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt
# 0 Train accuracy: 0.572794 Test accuracy: 0.578235
# 1 Train accuracy: 0.580927 Test accuracy: 0.589435
# 2 Train accuracy: 0.577148 Test accuracy: 0.583584
# 3 Train accuracy: 0.57358 Test accuracy: 0.583751
# 4 Train accuracy: 0.570647 Test accuracy: 0.581077
# Finished training

# %% [markdown]
# ## Visualize the Feature Maps
# The following code is useful to look into the activations of convolutional and pooling layers

# %%
[n.name for n in tf.get_default_graph().as_graph_def().node]
# Out:
# ['tensors/component_0',
#  'tensors/component_1',
#  'tensors_1/component_0',
#  'tensors_1/component_1',
#  'tensors/component_0_1',
#  'tensors/component_1_1',
#  'tensors_1/component_0_1',
#  'tensors_1/component_1_1',
#  'inputs/X',
#  'inputs/Reshape/shape',
#  'inputs/Reshape',
#  'inputs/y',
#  'inputs/keep_prob',
#  'conv2d/kernel/Initializer/random_uniform/shape',
#  'conv2d/kernel/Initializer/random_uniform/min',
#  'conv2d/kernel/Initializer/random_uniform/max',
#  'conv2d/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d/kernel/Initializer/random_uniform/sub',
#  'conv2d/kernel/Initializer/random_uniform/mul',
#  'conv2d/kernel/Initializer/random_uniform',
#  'conv2d/kernel',
#  'conv2d/kernel/Assign',
#  'conv2d/kernel/read',
#  'conv2d/bias/Initializer/zeros',
#  'conv2d/bias',
#  'conv2d/bias/Assign',
#  'conv2d/bias/read',
#  'conv/conv2d/dilation_rate',
#  'conv/conv2d/Conv2D',
#  'conv/conv2d/BiasAdd',
#  'conv/conv2d/Relu',
#  'conv/dropout/Shape',
#  'conv/dropout/random_uniform/min',
#  'conv/dropout/random_uniform/max',
#  'conv/dropout/random_uniform/RandomUniform',
#  'conv/dropout/random_uniform/sub',
#  'conv/dropout/random_uniform/mul',
#  'conv/dropout/random_uniform',
#  'conv/dropout/add',
#  'conv/dropout/Floor',
#  'conv/dropout/div',
#  'conv/dropout/mul',
#  'conv2d_1/kernel/Initializer/random_uniform/shape',
#  'conv2d_1/kernel/Initializer/random_uniform/min',
#  'conv2d_1/kernel/Initializer/random_uniform/max',
#  'conv2d_1/kernel/Initializer/random_uniform/RandomUniform',
#  'conv2d_1/kernel/Initializer/random_uniform/sub',
#  'conv2d_1/kernel/Initializer/random_uniform/mul',
#  'conv2d_1/kernel/Initializer/random_uniform',
#  'conv2d_1/kernel',
#  'conv2d_1/kernel/Assign',
#  'conv2d_1/kernel/read',
#  'conv2d_1/bias/Initializer/zeros',
#  'conv2d_1/bias',
#  'conv2d_1/bias/Assign',
#  'conv2d_1/bias/read',
#  'conv/conv2d_2/dilation_rate',
#  'conv/conv2d_2/Conv2D',
#  'conv/conv2d_2/BiasAdd',
#  'conv/conv2d_2/Relu',
#  'conv/dropout_1/Shape',
#  'conv/dropout_1/random_uniform/min',
#  'conv/dropout_1/random_uniform/max',
#  'conv/dropout_1/random_uniform/RandomUniform',
#  'conv/dropout_1/random_uniform/sub',
#  'conv/dropout_1/random_uniform/mul',
#  'conv/dropout_1/random_uniform',
#  'conv/dropout_1/add',
#  'conv/dropout_1/Floor',
#  'conv/dropout_1/div',
#  'conv/dropout_1/mul',
#  'pool3/MaxPool',
#  'pool3/Reshape/shape',
#  'pool3/Reshape',
#  'fc1/kernel/Initializer/random_uniform/shape',
#  'fc1/kernel/Initializer/random_uniform/min',
#  'fc1/kernel/Initializer/random_uniform/max',
#  'fc1/kernel/Initializer/random_uniform/RandomUniform',
#  'fc1/kernel/Initializer/random_uniform/sub',
#  'fc1/kernel/Initializer/random_uniform/mul',
#  'fc1/kernel/Initializer/random_uniform',
#  'fc1/kernel',
#  'fc1/kernel/Assign',
#  'fc1/kernel/read',
#  'fc1/bias/Initializer/zeros',
#  'fc1/bias',
#  'fc1/bias/Assign',
#  'fc1/bias/read',
#  'fc1/fc1/MatMul',
#  'fc1/fc1/BiasAdd',
#  'fc1/fc1/Relu',
#  'fc1/dropout/Shape',
#  'fc1/dropout/random_uniform/min',
#  'fc1/dropout/random_uniform/max',
#  'fc1/dropout/random_uniform/RandomUniform',
#  'fc1/dropout/random_uniform/sub',
#  'fc1/dropout/random_uniform/mul',
#  'fc1/dropout/random_uniform',
#  'fc1/dropout/add',
#  'fc1/dropout/Floor',
#  'fc1/dropout/div',
#  'fc1/dropout/mul',
#  'fc2/kernel/Initializer/random_uniform/shape',
#  'fc2/kernel/Initializer/random_uniform/min',
#  'fc2/kernel/Initializer/random_uniform/max',
#  'fc2/kernel/Initializer/random_uniform/RandomUniform',
#  'fc2/kernel/Initializer/random_uniform/sub',
#  'fc2/kernel/Initializer/random_uniform/mul',
#  'fc2/kernel/Initializer/random_uniform',
#  'fc2/kernel',
#  'fc2/kernel/Assign',
#  'fc2/kernel/read',
#  'fc2/bias/Initializer/zeros',
#  'fc2/bias',
#  'fc2/bias/Assign',
#  'fc2/bias/read',
#  'fc2/fc2/MatMul',
#  'fc2/fc2/BiasAdd',
#  'fc2/fc2/Relu',
#  'dense/kernel/Initializer/random_uniform/shape',
#  'dense/kernel/Initializer/random_uniform/min',
#  'dense/kernel/Initializer/random_uniform/max',
#  'dense/kernel/Initializer/random_uniform/RandomUniform',
#  'dense/kernel/Initializer/random_uniform/sub',
#  'dense/kernel/Initializer/random_uniform/mul',
#  'dense/kernel/Initializer/random_uniform',
#  'dense/kernel',
#  'dense/kernel/Assign',
#  'dense/kernel/read',
#  'dense/bias/Initializer/zeros',
#  'dense/bias',
#  'dense/bias/Assign',
#  'dense/bias/read',
#  'output/dense/MatMul',
#  'output/dense/BiasAdd',
#  'output/Softmax',
#  'train/SparseSoftmaxCrossEntropyWithLogits/Shape',
#  'train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits',
#  'train/Const',
#  'train/Mean',
#  'train/gradients/Shape',
#  'train/gradients/Const',
#  'train/gradients/Fill',
#  'train/gradients/train/Mean_grad/Reshape/shape',
#  'train/gradients/train/Mean_grad/Reshape',
#  'train/gradients/train/Mean_grad/Shape',
#  'train/gradients/train/Mean_grad/Tile',
#  'train/gradients/train/Mean_grad/Shape_1',
#  'train/gradients/train/Mean_grad/Shape_2',
#  'train/gradients/train/Mean_grad/Const',
#  'train/gradients/train/Mean_grad/Prod',
#  'train/gradients/train/Mean_grad/Const_1',
#  'train/gradients/train/Mean_grad/Prod_1',
#  'train/gradients/train/Mean_grad/Maximum/y',
#  'train/gradients/train/Mean_grad/Maximum',
#  'train/gradients/train/Mean_grad/floordiv',
#  'train/gradients/train/Mean_grad/Cast',
#  'train/gradients/train/Mean_grad/truediv',
#  'train/gradients/zeros_like',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'train/gradients/train/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul',
#  'train/gradients/output/dense/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/output/dense/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/output/dense/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/output/dense/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/output/dense/MatMul_grad/MatMul',
#  'train/gradients/output/dense/MatMul_grad/MatMul_1',
#  'train/gradients/output/dense/MatMul_grad/tuple/group_deps',
#  'train/gradients/output/dense/MatMul_grad/tuple/control_dependency',
#  'train/gradients/output/dense/MatMul_grad/tuple/control_dependency_1',
#  'train/gradients/fc2/fc2/Relu_grad/ReluGrad',
#  'train/gradients/fc2/fc2/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/fc2/fc2/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/fc2/fc2/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/fc2/fc2/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/fc2/fc2/MatMul_grad/MatMul',
#  'train/gradients/fc2/fc2/MatMul_grad/MatMul_1',
#  'train/gradients/fc2/fc2/MatMul_grad/tuple/group_deps',
#  'train/gradients/fc2/fc2/MatMul_grad/tuple/control_dependency',
#  'train/gradients/fc2/fc2/MatMul_grad/tuple/control_dependency_1',
#  'train/gradients/fc1/dropout/mul_grad/Shape',
#  'train/gradients/fc1/dropout/mul_grad/Shape_1',
#  'train/gradients/fc1/dropout/mul_grad/BroadcastGradientArgs',
#  'train/gradients/fc1/dropout/mul_grad/mul',
#  'train/gradients/fc1/dropout/mul_grad/Sum',
#  'train/gradients/fc1/dropout/mul_grad/Reshape',
#  'train/gradients/fc1/dropout/mul_grad/mul_1',
#  'train/gradients/fc1/dropout/mul_grad/Sum_1',
#  'train/gradients/fc1/dropout/mul_grad/Reshape_1',
#  'train/gradients/fc1/dropout/mul_grad/tuple/group_deps',
#  'train/gradients/fc1/dropout/mul_grad/tuple/control_dependency',
#  'train/gradients/fc1/dropout/mul_grad/tuple/control_dependency_1',
#  'train/gradients/fc1/dropout/div_grad/Shape',
#  'train/gradients/fc1/dropout/div_grad/Shape_1',
#  'train/gradients/fc1/dropout/div_grad/BroadcastGradientArgs',
#  'train/gradients/fc1/dropout/div_grad/RealDiv',
#  'train/gradients/fc1/dropout/div_grad/Sum',
#  'train/gradients/fc1/dropout/div_grad/Reshape',
#  'train/gradients/fc1/dropout/div_grad/Neg',
#  'train/gradients/fc1/dropout/div_grad/RealDiv_1',
#  'train/gradients/fc1/dropout/div_grad/RealDiv_2',
#  'train/gradients/fc1/dropout/div_grad/mul',
#  'train/gradients/fc1/dropout/div_grad/Sum_1',
#  'train/gradients/fc1/dropout/div_grad/Reshape_1',
#  'train/gradients/fc1/dropout/div_grad/tuple/group_deps',
#  'train/gradients/fc1/dropout/div_grad/tuple/control_dependency',
#  'train/gradients/fc1/dropout/div_grad/tuple/control_dependency_1',
#  'train/gradients/fc1/fc1/Relu_grad/ReluGrad',
#  'train/gradients/fc1/fc1/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/fc1/fc1/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/fc1/fc1/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/fc1/fc1/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/fc1/fc1/MatMul_grad/MatMul',
#  'train/gradients/fc1/fc1/MatMul_grad/MatMul_1',
#  'train/gradients/fc1/fc1/MatMul_grad/tuple/group_deps',
#  'train/gradients/fc1/fc1/MatMul_grad/tuple/control_dependency',
#  'train/gradients/fc1/fc1/MatMul_grad/tuple/control_dependency_1',
#  'train/gradients/pool3/Reshape_grad/Shape',
#  'train/gradients/pool3/Reshape_grad/Reshape',
#  'train/gradients/pool3/MaxPool_grad/MaxPoolGrad',
#  'train/gradients/conv/dropout_1/mul_grad/Shape',
#  'train/gradients/conv/dropout_1/mul_grad/Shape_1',
#  'train/gradients/conv/dropout_1/mul_grad/BroadcastGradientArgs',
#  'train/gradients/conv/dropout_1/mul_grad/mul',
#  'train/gradients/conv/dropout_1/mul_grad/Sum',
#  'train/gradients/conv/dropout_1/mul_grad/Reshape',
#  'train/gradients/conv/dropout_1/mul_grad/mul_1',
#  'train/gradients/conv/dropout_1/mul_grad/Sum_1',
#  'train/gradients/conv/dropout_1/mul_grad/Reshape_1',
#  'train/gradients/conv/dropout_1/mul_grad/tuple/group_deps',
#  'train/gradients/conv/dropout_1/mul_grad/tuple/control_dependency',
#  'train/gradients/conv/dropout_1/mul_grad/tuple/control_dependency_1',
#  'train/gradients/conv/dropout_1/div_grad/Shape',
#  'train/gradients/conv/dropout_1/div_grad/Shape_1',
#  'train/gradients/conv/dropout_1/div_grad/BroadcastGradientArgs',
#  'train/gradients/conv/dropout_1/div_grad/RealDiv',
#  'train/gradients/conv/dropout_1/div_grad/Sum',
#  'train/gradients/conv/dropout_1/div_grad/Reshape',
#  'train/gradients/conv/dropout_1/div_grad/Neg',
#  'train/gradients/conv/dropout_1/div_grad/RealDiv_1',
#  'train/gradients/conv/dropout_1/div_grad/RealDiv_2',
#  'train/gradients/conv/dropout_1/div_grad/mul',
#  'train/gradients/conv/dropout_1/div_grad/Sum_1',
#  'train/gradients/conv/dropout_1/div_grad/Reshape_1',
#  'train/gradients/conv/dropout_1/div_grad/tuple/group_deps',
#  'train/gradients/conv/dropout_1/div_grad/tuple/control_dependency',
#  'train/gradients/conv/dropout_1/div_grad/tuple/control_dependency_1',
#  'train/gradients/conv/conv2d_2/Relu_grad/ReluGrad',
#  'train/gradients/conv/conv2d_2/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/ShapeN',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency_1',
#  'train/gradients/conv/dropout/mul_grad/Shape',
#  'train/gradients/conv/dropout/mul_grad/Shape_1',
#  'train/gradients/conv/dropout/mul_grad/BroadcastGradientArgs',
#  'train/gradients/conv/dropout/mul_grad/mul',
#  'train/gradients/conv/dropout/mul_grad/Sum',
#  'train/gradients/conv/dropout/mul_grad/Reshape',
#  'train/gradients/conv/dropout/mul_grad/mul_1',
#  'train/gradients/conv/dropout/mul_grad/Sum_1',
#  'train/gradients/conv/dropout/mul_grad/Reshape_1',
#  'train/gradients/conv/dropout/mul_grad/tuple/group_deps',
#  'train/gradients/conv/dropout/mul_grad/tuple/control_dependency',
#  'train/gradients/conv/dropout/mul_grad/tuple/control_dependency_1',
#  'train/gradients/conv/dropout/div_grad/Shape',
#  'train/gradients/conv/dropout/div_grad/Shape_1',
#  'train/gradients/conv/dropout/div_grad/BroadcastGradientArgs',
#  'train/gradients/conv/dropout/div_grad/RealDiv',
#  'train/gradients/conv/dropout/div_grad/Sum',
#  'train/gradients/conv/dropout/div_grad/Reshape',
#  'train/gradients/conv/dropout/div_grad/Neg',
#  'train/gradients/conv/dropout/div_grad/RealDiv_1',
#  'train/gradients/conv/dropout/div_grad/RealDiv_2',
#  'train/gradients/conv/dropout/div_grad/mul',
#  'train/gradients/conv/dropout/div_grad/Sum_1',
#  'train/gradients/conv/dropout/div_grad/Reshape_1',
#  'train/gradients/conv/dropout/div_grad/tuple/group_deps',
#  'train/gradients/conv/dropout/div_grad/tuple/control_dependency',
#  'train/gradients/conv/dropout/div_grad/tuple/control_dependency_1',
#  'train/gradients/conv/conv2d/Relu_grad/ReluGrad',
#  'train/gradients/conv/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train/gradients/conv/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train/gradients/conv/conv2d/Conv2D_grad/ShapeN',
#  'train/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train/gradients/conv/conv2d/Conv2D_grad/tuple/group_deps',
#  'train/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train/beta1_power/initial_value',
#  'train/beta1_power',
#  'train/beta1_power/Assign',
#  'train/beta1_power/read',
#  'train/beta2_power/initial_value',
#  'train/beta2_power',
#  'train/beta2_power/Assign',
#  'train/beta2_power/read',
#  'conv2d/kernel/Adam/Initializer/zeros',
#  'conv2d/kernel/Adam',
#  'conv2d/kernel/Adam/Assign',
#  'conv2d/kernel/Adam/read',
#  'conv2d/kernel/Adam_1/Initializer/zeros',
#  'conv2d/kernel/Adam_1',
#  'conv2d/kernel/Adam_1/Assign',
#  'conv2d/kernel/Adam_1/read',
#  'conv2d/bias/Adam/Initializer/zeros',
#  'conv2d/bias/Adam',
#  'conv2d/bias/Adam/Assign',
#  'conv2d/bias/Adam/read',
#  'conv2d/bias/Adam_1/Initializer/zeros',
#  'conv2d/bias/Adam_1',
#  'conv2d/bias/Adam_1/Assign',
#  'conv2d/bias/Adam_1/read',
#  'conv2d_1/kernel/Adam/Initializer/zeros',
#  'conv2d_1/kernel/Adam',
#  'conv2d_1/kernel/Adam/Assign',
#  'conv2d_1/kernel/Adam/read',
#  'conv2d_1/kernel/Adam_1/Initializer/zeros',
#  'conv2d_1/kernel/Adam_1',
#  'conv2d_1/kernel/Adam_1/Assign',
#  'conv2d_1/kernel/Adam_1/read',
#  'conv2d_1/bias/Adam/Initializer/zeros',
#  'conv2d_1/bias/Adam',
#  'conv2d_1/bias/Adam/Assign',
#  'conv2d_1/bias/Adam/read',
#  'conv2d_1/bias/Adam_1/Initializer/zeros',
#  'conv2d_1/bias/Adam_1',
#  'conv2d_1/bias/Adam_1/Assign',
#  'conv2d_1/bias/Adam_1/read',
#  'fc1/kernel/Adam/Initializer/zeros',
#  'fc1/kernel/Adam',
#  'fc1/kernel/Adam/Assign',
#  'fc1/kernel/Adam/read',
#  'fc1/kernel/Adam_1/Initializer/zeros',
#  'fc1/kernel/Adam_1',
#  'fc1/kernel/Adam_1/Assign',
#  'fc1/kernel/Adam_1/read',
#  'fc1/bias/Adam/Initializer/zeros',
#  'fc1/bias/Adam',
#  'fc1/bias/Adam/Assign',
#  'fc1/bias/Adam/read',
#  'fc1/bias/Adam_1/Initializer/zeros',
#  'fc1/bias/Adam_1',
#  'fc1/bias/Adam_1/Assign',
#  'fc1/bias/Adam_1/read',
#  'fc2/kernel/Adam/Initializer/zeros',
#  'fc2/kernel/Adam',
#  'fc2/kernel/Adam/Assign',
#  'fc2/kernel/Adam/read',
#  'fc2/kernel/Adam_1/Initializer/zeros',
#  'fc2/kernel/Adam_1',
#  'fc2/kernel/Adam_1/Assign',
#  'fc2/kernel/Adam_1/read',
#  'fc2/bias/Adam/Initializer/zeros',
#  'fc2/bias/Adam',
#  'fc2/bias/Adam/Assign',
#  'fc2/bias/Adam/read',
#  'fc2/bias/Adam_1/Initializer/zeros',
#  'fc2/bias/Adam_1',
#  'fc2/bias/Adam_1/Assign',
#  'fc2/bias/Adam_1/read',
#  'dense/kernel/Adam/Initializer/zeros',
#  'dense/kernel/Adam',
#  'dense/kernel/Adam/Assign',
#  'dense/kernel/Adam/read',
#  'dense/kernel/Adam_1/Initializer/zeros',
#  'dense/kernel/Adam_1',
#  'dense/kernel/Adam_1/Assign',
#  'dense/kernel/Adam_1/read',
#  'dense/bias/Adam/Initializer/zeros',
#  'dense/bias/Adam',
#  'dense/bias/Adam/Assign',
#  'dense/bias/Adam/read',
#  'dense/bias/Adam_1/Initializer/zeros',
#  'dense/bias/Adam_1',
#  'dense/bias/Adam_1/Assign',
#  'dense/bias/Adam_1/read',
#  'train/Adam/learning_rate',
#  'train/Adam/beta1',
#  'train/Adam/beta2',
#  'train/Adam/epsilon',
#  'train/Adam/update_conv2d/kernel/ApplyAdam',
#  'train/Adam/update_conv2d/bias/ApplyAdam',
#  'train/Adam/update_conv2d_1/kernel/ApplyAdam',
#  'train/Adam/update_conv2d_1/bias/ApplyAdam',
#  'train/Adam/update_fc1/kernel/ApplyAdam',
#  'train/Adam/update_fc1/bias/ApplyAdam',
#  'train/Adam/update_fc2/kernel/ApplyAdam',
#  'train/Adam/update_fc2/bias/ApplyAdam',
#  'train/Adam/update_dense/kernel/ApplyAdam',
#  'train/Adam/update_dense/bias/ApplyAdam',
#  'train/Adam/mul',
#  'train/Adam/Assign',
#  'train/Adam/mul_1',
#  'train/Adam/Assign_1',
#  'train/Adam',
#  'eval/in_top_k/InTopKV2/k',
#  'eval/in_top_k/InTopKV2',
#  'eval/Cast',
#  'eval/Const',
#  'eval/Mean',
#  'init_and_save/init',
#  'init_and_save/save/Const',
#  'init_and_save/save/SaveV2/tensor_names',
#  'init_and_save/save/SaveV2/shape_and_slices',
#  'init_and_save/save/SaveV2',
#  'init_and_save/save/control_dependency',
#  'init_and_save/save/RestoreV2/tensor_names',
#  'init_and_save/save/RestoreV2/shape_and_slices',
#  'init_and_save/save/RestoreV2',
#  'init_and_save/save/Assign',
#  'init_and_save/save/RestoreV2_1/tensor_names',
#  'init_and_save/save/RestoreV2_1/shape_and_slices',
#  'init_and_save/save/RestoreV2_1',
#  'init_and_save/save/Assign_1',
#  'init_and_save/save/RestoreV2_2/tensor_names',
#  'init_and_save/save/RestoreV2_2/shape_and_slices',
#  'init_and_save/save/RestoreV2_2',
#  'init_and_save/save/Assign_2',
#  'init_and_save/save/RestoreV2_3/tensor_names',
#  'init_and_save/save/RestoreV2_3/shape_and_slices',
#  'init_and_save/save/RestoreV2_3',
#  'init_and_save/save/Assign_3',
#  'init_and_save/save/RestoreV2_4/tensor_names',
#  'init_and_save/save/RestoreV2_4/shape_and_slices',
#  'init_and_save/save/RestoreV2_4',
#  'init_and_save/save/Assign_4',
#  'init_and_save/save/RestoreV2_5/tensor_names',
#  'init_and_save/save/RestoreV2_5/shape_and_slices',
#  'init_and_save/save/RestoreV2_5',
#  'init_and_save/save/Assign_5',
#  'init_and_save/save/RestoreV2_6/tensor_names',
#  'init_and_save/save/RestoreV2_6/shape_and_slices',
#  'init_and_save/save/RestoreV2_6',
#  'init_and_save/save/Assign_6',
#  'init_and_save/save/RestoreV2_7/tensor_names',
#  'init_and_save/save/RestoreV2_7/shape_and_slices',
#  'init_and_save/save/RestoreV2_7',
#  'init_and_save/save/Assign_7',
#  'init_and_save/save/RestoreV2_8/tensor_names',
#  'init_and_save/save/RestoreV2_8/shape_and_slices',
#  'init_and_save/save/RestoreV2_8',
#  'init_and_save/save/Assign_8',
#  'init_and_save/save/RestoreV2_9/tensor_names',
#  'init_and_save/save/RestoreV2_9/shape_and_slices',
#  'init_and_save/save/RestoreV2_9',
#  'init_and_save/save/Assign_9',
#  'init_and_save/save/RestoreV2_10/tensor_names',
#  'init_and_save/save/RestoreV2_10/shape_and_slices',
#  'init_and_save/save/RestoreV2_10',
#  'init_and_save/save/Assign_10',
#  'init_and_save/save/RestoreV2_11/tensor_names',
#  'init_and_save/save/RestoreV2_11/shape_and_slices',
#  'init_and_save/save/RestoreV2_11',
#  'init_and_save/save/Assign_11',
#  'init_and_save/save/RestoreV2_12/tensor_names',
#  'init_and_save/save/RestoreV2_12/shape_and_slices',
#  'init_and_save/save/RestoreV2_12',
#  'init_and_save/save/Assign_12',
#  'init_and_save/save/RestoreV2_13/tensor_names',
#  'init_and_save/save/RestoreV2_13/shape_and_slices',
#  'init_and_save/save/RestoreV2_13',
#  'init_and_save/save/Assign_13',
#  'init_and_save/save/RestoreV2_14/tensor_names',
#  'init_and_save/save/RestoreV2_14/shape_and_slices',
#  'init_and_save/save/RestoreV2_14',
#  'init_and_save/save/Assign_14',
#  'init_and_save/save/RestoreV2_15/tensor_names',
#  'init_and_save/save/RestoreV2_15/shape_and_slices',
#  'init_and_save/save/RestoreV2_15',
#  'init_and_save/save/Assign_15',
#  'init_and_save/save/RestoreV2_16/tensor_names',
#  'init_and_save/save/RestoreV2_16/shape_and_slices',
#  'init_and_save/save/RestoreV2_16',
#  'init_and_save/save/Assign_16',
#  'init_and_save/save/RestoreV2_17/tensor_names',
#  'init_and_save/save/RestoreV2_17/shape_and_slices',
#  'init_and_save/save/RestoreV2_17',
#  'init_and_save/save/Assign_17',
#  'init_and_save/save/RestoreV2_18/tensor_names',
#  'init_and_save/save/RestoreV2_18/shape_and_slices',
#  'init_and_save/save/RestoreV2_18',
#  'init_and_save/save/Assign_18',
#  'init_and_save/save/RestoreV2_19/tensor_names',
#  'init_and_save/save/RestoreV2_19/shape_and_slices',
#  'init_and_save/save/RestoreV2_19',
#  'init_and_save/save/Assign_19',
#  'init_and_save/save/RestoreV2_20/tensor_names',
#  'init_and_save/save/RestoreV2_20/shape_and_slices',
#  'init_and_save/save/RestoreV2_20',
#  'init_and_save/save/Assign_20',
#  'init_and_save/save/RestoreV2_21/tensor_names',
#  'init_and_save/save/RestoreV2_21/shape_and_slices',
#  'init_and_save/save/RestoreV2_21',
#  'init_and_save/save/Assign_21',
#  'init_and_save/save/RestoreV2_22/tensor_names',
#  'init_and_save/save/RestoreV2_22/shape_and_slices',
#  'init_and_save/save/RestoreV2_22',
#  'init_and_save/save/Assign_22',
#  'init_and_save/save/RestoreV2_23/tensor_names',
#  'init_and_save/save/RestoreV2_23/shape_and_slices',
#  'init_and_save/save/RestoreV2_23',
#  'init_and_save/save/Assign_23',
#  'init_and_save/save/RestoreV2_24/tensor_names',
#  'init_and_save/save/RestoreV2_24/shape_and_slices',
#  'init_and_save/save/RestoreV2_24',
#  'init_and_save/save/Assign_24',
#  'init_and_save/save/RestoreV2_25/tensor_names',
#  'init_and_save/save/RestoreV2_25/shape_and_slices',
#  'init_and_save/save/RestoreV2_25',
#  'init_and_save/save/Assign_25',
#  'init_and_save/save/RestoreV2_26/tensor_names',
#  'init_and_save/save/RestoreV2_26/shape_and_slices',
#  'init_and_save/save/RestoreV2_26',
#  'init_and_save/save/Assign_26',
#  'init_and_save/save/RestoreV2_27/tensor_names',
#  'init_and_save/save/RestoreV2_27/shape_and_slices',
#  'init_and_save/save/RestoreV2_27',
#  'init_and_save/save/Assign_27',
#  'init_and_save/save/RestoreV2_28/tensor_names',
#  'init_and_save/save/RestoreV2_28/shape_and_slices',
#  'init_and_save/save/RestoreV2_28',
#  'init_and_save/save/Assign_28',
#  'init_and_save/save/RestoreV2_29/tensor_names',
#  'init_and_save/save/RestoreV2_29/shape_and_slices',
#  'init_and_save/save/RestoreV2_29',
#  'init_and_save/save/Assign_29',
#  'init_and_save/save/RestoreV2_30/tensor_names',
#  'init_and_save/save/RestoreV2_30/shape_and_slices',
#  'init_and_save/save/RestoreV2_30',
#  'init_and_save/save/Assign_30',
#  'init_and_save/save/RestoreV2_31/tensor_names',
#  'init_and_save/save/RestoreV2_31/shape_and_slices',
#  'init_and_save/save/RestoreV2_31',
#  'init_and_save/save/Assign_31',
#  'init_and_save/save/restore_all',
#  'Iterator',
#  'TensorSliceDataset',
#  'BatchDataset/batch_size',
#  'BatchDataset',
#  'MakeIterator',
#  'IteratorGetNext',
#  'fc2_023678/kernel/Initializer/random_uniform/shape',
#  'fc2_023678/kernel/Initializer/random_uniform/min',
#  'fc2_023678/kernel/Initializer/random_uniform/max',
#  'fc2_023678/kernel/Initializer/random_uniform/RandomUniform',
#  'fc2_023678/kernel/Initializer/random_uniform/sub',
#  'fc2_023678/kernel/Initializer/random_uniform/mul',
#  'fc2_023678/kernel/Initializer/random_uniform',
#  'fc2_023678/kernel',
#  'fc2_023678/kernel/Assign',
#  'fc2_023678/kernel/read',
#  'fc2_023678/bias/Initializer/zeros',
#  'fc2_023678/bias',
#  'fc2_023678/bias/Assign',
#  'fc2_023678/bias/read',
#  'fc2_023678/fc2_023678/MatMul',
#  'fc2_023678/fc2_023678/BiasAdd',
#  'output_023678/kernel/Initializer/random_uniform/shape',
#  'output_023678/kernel/Initializer/random_uniform/min',
#  'output_023678/kernel/Initializer/random_uniform/max',
#  'output_023678/kernel/Initializer/random_uniform/RandomUniform',
#  'output_023678/kernel/Initializer/random_uniform/sub',
#  'output_023678/kernel/Initializer/random_uniform/mul',
#  'output_023678/kernel/Initializer/random_uniform',
#  'output_023678/kernel',
#  'output_023678/kernel/Assign',
#  'output_023678/kernel/read',
#  'output_023678/bias/Initializer/zeros',
#  'output_023678/bias',
#  'output_023678/bias/Assign',
#  'output_023678/bias/read',
#  'softmax_023678/output_023678/MatMul',
#  'softmax_023678/output_023678/BiasAdd',
#  'softmax_023678/Y_proba_023678',
#  'train_023678/SparseSoftmaxCrossEntropyWithLogits/Shape',
#  'train_023678/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits',
#  'train_023678/Const',
#  'train_023678/Mean',
#  'train_023678/gradients/Shape',
#  'train_023678/gradients/Const',
#  'train_023678/gradients/Fill',
#  'train_023678/gradients/train_023678/Mean_grad/Reshape/shape',
#  'train_023678/gradients/train_023678/Mean_grad/Reshape',
#  'train_023678/gradients/train_023678/Mean_grad/Shape',
#  'train_023678/gradients/train_023678/Mean_grad/Tile',
#  'train_023678/gradients/train_023678/Mean_grad/Shape_1',
#  'train_023678/gradients/train_023678/Mean_grad/Shape_2',
#  'train_023678/gradients/train_023678/Mean_grad/Const',
#  'train_023678/gradients/train_023678/Mean_grad/Prod',
#  'train_023678/gradients/train_023678/Mean_grad/Const_1',
#  'train_023678/gradients/train_023678/Mean_grad/Prod_1',
#  'train_023678/gradients/train_023678/Mean_grad/Maximum/y',
#  'train_023678/gradients/train_023678/Mean_grad/Maximum',
#  'train_023678/gradients/train_023678/Mean_grad/floordiv',
#  'train_023678/gradients/train_023678/Mean_grad/Cast',
#  'train_023678/gradients/train_023678/Mean_grad/truediv',
#  'train_023678/gradients/zeros_like',
#  'train_023678/gradients/train_023678/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient',
#  'train_023678/gradients/train_023678/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'train_023678/gradients/train_023678/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'train_023678/gradients/train_023678/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul',
#  'train_023678/gradients/softmax_023678/output_023678/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/softmax_023678/output_023678/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/softmax_023678/output_023678/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/softmax_023678/output_023678/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/softmax_023678/output_023678/MatMul_grad/MatMul',
#  'train_023678/gradients/softmax_023678/output_023678/MatMul_grad/MatMul_1',
#  'train_023678/gradients/softmax_023678/output_023678/MatMul_grad/tuple/group_deps',
#  'train_023678/gradients/softmax_023678/output_023678/MatMul_grad/tuple/control_dependency',
#  'train_023678/gradients/softmax_023678/output_023678/MatMul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc2_023678/fc2_023678/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/fc2_023678/fc2_023678/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/fc2_023678/fc2_023678/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/fc2_023678/fc2_023678/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc2_023678/fc2_023678/MatMul_grad/MatMul',
#  'train_023678/gradients/fc2_023678/fc2_023678/MatMul_grad/MatMul_1',
#  'train_023678/gradients/fc2_023678/fc2_023678/MatMul_grad/tuple/group_deps',
#  'train_023678/gradients/fc2_023678/fc2_023678/MatMul_grad/tuple/control_dependency',
#  'train_023678/gradients/fc2_023678/fc2_023678/MatMul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc2/fc2/Relu_grad/ReluGrad',
#  'train_023678/gradients/fc2/fc2/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/fc2/fc2/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/fc2/fc2/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/fc2/fc2/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc2/fc2/MatMul_grad/MatMul',
#  'train_023678/gradients/fc2/fc2/MatMul_grad/MatMul_1',
#  'train_023678/gradients/fc2/fc2/MatMul_grad/tuple/group_deps',
#  'train_023678/gradients/fc2/fc2/MatMul_grad/tuple/control_dependency',
#  'train_023678/gradients/fc2/fc2/MatMul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc1/dropout/mul_grad/Shape',
#  'train_023678/gradients/fc1/dropout/mul_grad/Shape_1',
#  'train_023678/gradients/fc1/dropout/mul_grad/BroadcastGradientArgs',
#  'train_023678/gradients/fc1/dropout/mul_grad/mul',
#  'train_023678/gradients/fc1/dropout/mul_grad/Sum',
#  'train_023678/gradients/fc1/dropout/mul_grad/Reshape',
#  'train_023678/gradients/fc1/dropout/mul_grad/mul_1',
#  'train_023678/gradients/fc1/dropout/mul_grad/Sum_1',
#  'train_023678/gradients/fc1/dropout/mul_grad/Reshape_1',
#  'train_023678/gradients/fc1/dropout/mul_grad/tuple/group_deps',
#  'train_023678/gradients/fc1/dropout/mul_grad/tuple/control_dependency',
#  'train_023678/gradients/fc1/dropout/mul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc1/dropout/div_grad/Shape',
#  'train_023678/gradients/fc1/dropout/div_grad/Shape_1',
#  'train_023678/gradients/fc1/dropout/div_grad/BroadcastGradientArgs',
#  'train_023678/gradients/fc1/dropout/div_grad/RealDiv',
#  'train_023678/gradients/fc1/dropout/div_grad/Sum',
#  'train_023678/gradients/fc1/dropout/div_grad/Reshape',
#  'train_023678/gradients/fc1/dropout/div_grad/Neg',
#  'train_023678/gradients/fc1/dropout/div_grad/RealDiv_1',
#  'train_023678/gradients/fc1/dropout/div_grad/RealDiv_2',
#  'train_023678/gradients/fc1/dropout/div_grad/mul',
#  'train_023678/gradients/fc1/dropout/div_grad/Sum_1',
#  'train_023678/gradients/fc1/dropout/div_grad/Reshape_1',
#  'train_023678/gradients/fc1/dropout/div_grad/tuple/group_deps',
#  'train_023678/gradients/fc1/dropout/div_grad/tuple/control_dependency',
#  'train_023678/gradients/fc1/dropout/div_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc1/fc1/Relu_grad/ReluGrad',
#  'train_023678/gradients/fc1/fc1/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/fc1/fc1/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/fc1/fc1/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/fc1/fc1/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/fc1/fc1/MatMul_grad/MatMul',
#  'train_023678/gradients/fc1/fc1/MatMul_grad/MatMul_1',
#  'train_023678/gradients/fc1/fc1/MatMul_grad/tuple/group_deps',
#  'train_023678/gradients/fc1/fc1/MatMul_grad/tuple/control_dependency',
#  'train_023678/gradients/fc1/fc1/MatMul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/pool3/Reshape_grad/Shape',
#  'train_023678/gradients/pool3/Reshape_grad/Reshape',
#  'train_023678/gradients/pool3/MaxPool_grad/MaxPoolGrad',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Shape',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Shape_1',
#  'train_023678/gradients/conv/dropout_1/mul_grad/BroadcastGradientArgs',
#  'train_023678/gradients/conv/dropout_1/mul_grad/mul',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Sum',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Reshape',
#  'train_023678/gradients/conv/dropout_1/mul_grad/mul_1',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Sum_1',
#  'train_023678/gradients/conv/dropout_1/mul_grad/Reshape_1',
#  'train_023678/gradients/conv/dropout_1/mul_grad/tuple/group_deps',
#  'train_023678/gradients/conv/dropout_1/mul_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/dropout_1/mul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/dropout_1/div_grad/Shape',
#  'train_023678/gradients/conv/dropout_1/div_grad/Shape_1',
#  'train_023678/gradients/conv/dropout_1/div_grad/BroadcastGradientArgs',
#  'train_023678/gradients/conv/dropout_1/div_grad/RealDiv',
#  'train_023678/gradients/conv/dropout_1/div_grad/Sum',
#  'train_023678/gradients/conv/dropout_1/div_grad/Reshape',
#  'train_023678/gradients/conv/dropout_1/div_grad/Neg',
#  'train_023678/gradients/conv/dropout_1/div_grad/RealDiv_1',
#  'train_023678/gradients/conv/dropout_1/div_grad/RealDiv_2',
#  'train_023678/gradients/conv/dropout_1/div_grad/mul',
#  'train_023678/gradients/conv/dropout_1/div_grad/Sum_1',
#  'train_023678/gradients/conv/dropout_1/div_grad/Reshape_1',
#  'train_023678/gradients/conv/dropout_1/div_grad/tuple/group_deps',
#  'train_023678/gradients/conv/dropout_1/div_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/dropout_1/div_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/conv2d_2/Relu_grad/ReluGrad',
#  'train_023678/gradients/conv/conv2d_2/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/conv/conv2d_2/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/conv2d_2/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/ShapeN',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropInput',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/Conv2DBackpropFilter',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/tuple/group_deps',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/conv2d_2/Conv2D_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/dropout/mul_grad/Shape',
#  'train_023678/gradients/conv/dropout/mul_grad/Shape_1',
#  'train_023678/gradients/conv/dropout/mul_grad/BroadcastGradientArgs',
#  'train_023678/gradients/conv/dropout/mul_grad/mul',
#  'train_023678/gradients/conv/dropout/mul_grad/Sum',
#  'train_023678/gradients/conv/dropout/mul_grad/Reshape',
#  'train_023678/gradients/conv/dropout/mul_grad/mul_1',
#  'train_023678/gradients/conv/dropout/mul_grad/Sum_1',
#  'train_023678/gradients/conv/dropout/mul_grad/Reshape_1',
#  'train_023678/gradients/conv/dropout/mul_grad/tuple/group_deps',
#  'train_023678/gradients/conv/dropout/mul_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/dropout/mul_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/dropout/div_grad/Shape',
#  'train_023678/gradients/conv/dropout/div_grad/Shape_1',
#  'train_023678/gradients/conv/dropout/div_grad/BroadcastGradientArgs',
#  'train_023678/gradients/conv/dropout/div_grad/RealDiv',
#  'train_023678/gradients/conv/dropout/div_grad/Sum',
#  'train_023678/gradients/conv/dropout/div_grad/Reshape',
#  'train_023678/gradients/conv/dropout/div_grad/Neg',
#  'train_023678/gradients/conv/dropout/div_grad/RealDiv_1',
#  'train_023678/gradients/conv/dropout/div_grad/RealDiv_2',
#  'train_023678/gradients/conv/dropout/div_grad/mul',
#  'train_023678/gradients/conv/dropout/div_grad/Sum_1',
#  'train_023678/gradients/conv/dropout/div_grad/Reshape_1',
#  'train_023678/gradients/conv/dropout/div_grad/tuple/group_deps',
#  'train_023678/gradients/conv/dropout/div_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/dropout/div_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/conv2d/Relu_grad/ReluGrad',
#  'train_023678/gradients/conv/conv2d/BiasAdd_grad/BiasAddGrad',
#  'train_023678/gradients/conv/conv2d/BiasAdd_grad/tuple/group_deps',
#  'train_023678/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/conv2d/BiasAdd_grad/tuple/control_dependency_1',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/ShapeN',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropInput',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/Conv2DBackpropFilter',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/tuple/group_deps',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency',
#  'train_023678/gradients/conv/conv2d/Conv2D_grad/tuple/control_dependency_1',
#  'train_023678/beta1_power/initial_value',
#  'train_023678/beta1_power',
#  'train_023678/beta1_power/Assign',
#  'train_023678/beta1_power/read',
#  'train_023678/beta2_power/initial_value',
#  'train_023678/beta2_power',
#  'train_023678/beta2_power/Assign',
#  'train_023678/beta2_power/read',
#  'conv2d/kernel/adam_023678/Initializer/zeros',
#  'conv2d/kernel/adam_023678',
#  'conv2d/kernel/adam_023678/Assign',
#  'conv2d/kernel/adam_023678/read',
#  'conv2d/kernel/adam_023678_1/Initializer/zeros',
#  'conv2d/kernel/adam_023678_1',
#  'conv2d/kernel/adam_023678_1/Assign',
#  'conv2d/kernel/adam_023678_1/read',
#  'conv2d/bias/adam_023678/Initializer/zeros',
#  'conv2d/bias/adam_023678',
#  'conv2d/bias/adam_023678/Assign',
#  'conv2d/bias/adam_023678/read',
#  'conv2d/bias/adam_023678_1/Initializer/zeros',
#  'conv2d/bias/adam_023678_1',
#  'conv2d/bias/adam_023678_1/Assign',
#  'conv2d/bias/adam_023678_1/read',
#  'conv2d_1/kernel/adam_023678/Initializer/zeros',
#  'conv2d_1/kernel/adam_023678',
#  'conv2d_1/kernel/adam_023678/Assign',
#  'conv2d_1/kernel/adam_023678/read',
#  'conv2d_1/kernel/adam_023678_1/Initializer/zeros',
#  'conv2d_1/kernel/adam_023678_1',
#  'conv2d_1/kernel/adam_023678_1/Assign',
#  'conv2d_1/kernel/adam_023678_1/read',
#  'conv2d_1/bias/adam_023678/Initializer/zeros',
#  'conv2d_1/bias/adam_023678',
#  'conv2d_1/bias/adam_023678/Assign',
#  'conv2d_1/bias/adam_023678/read',
#  'conv2d_1/bias/adam_023678_1/Initializer/zeros',
#  'conv2d_1/bias/adam_023678_1',
#  'conv2d_1/bias/adam_023678_1/Assign',
#  'conv2d_1/bias/adam_023678_1/read',
#  'fc1/kernel/adam_023678/Initializer/zeros',
#  'fc1/kernel/adam_023678',
#  'fc1/kernel/adam_023678/Assign',
#  'fc1/kernel/adam_023678/read',
#  'fc1/kernel/adam_023678_1/Initializer/zeros',
#  'fc1/kernel/adam_023678_1',
#  'fc1/kernel/adam_023678_1/Assign',
#  'fc1/kernel/adam_023678_1/read',
#  'fc1/bias/adam_023678/Initializer/zeros',
#  'fc1/bias/adam_023678',
#  'fc1/bias/adam_023678/Assign',
#  'fc1/bias/adam_023678/read',
#  'fc1/bias/adam_023678_1/Initializer/zeros',
#  'fc1/bias/adam_023678_1',
#  'fc1/bias/adam_023678_1/Assign',
#  'fc1/bias/adam_023678_1/read',
#  'fc2/kernel/adam_023678/Initializer/zeros',
#  'fc2/kernel/adam_023678',
#  'fc2/kernel/adam_023678/Assign',
#  'fc2/kernel/adam_023678/read',
#  'fc2/kernel/adam_023678_1/Initializer/zeros',
#  'fc2/kernel/adam_023678_1',
#  'fc2/kernel/adam_023678_1/Assign',
#  'fc2/kernel/adam_023678_1/read',
#  'fc2/bias/adam_023678/Initializer/zeros',
#  'fc2/bias/adam_023678',
#  'fc2/bias/adam_023678/Assign',
#  'fc2/bias/adam_023678/read',
#  'fc2/bias/adam_023678_1/Initializer/zeros',
#  'fc2/bias/adam_023678_1',
#  'fc2/bias/adam_023678_1/Assign',
#  'fc2/bias/adam_023678_1/read',
#  'fc2_023678/kernel/adam_023678/Initializer/zeros',
#  'fc2_023678/kernel/adam_023678',
#  'fc2_023678/kernel/adam_023678/Assign',
#  'fc2_023678/kernel/adam_023678/read',
#  'fc2_023678/kernel/adam_023678_1/Initializer/zeros',
#  'fc2_023678/kernel/adam_023678_1',
#  'fc2_023678/kernel/adam_023678_1/Assign',
#  'fc2_023678/kernel/adam_023678_1/read',
#  'fc2_023678/bias/adam_023678/Initializer/zeros',
#  'fc2_023678/bias/adam_023678',
#  'fc2_023678/bias/adam_023678/Assign',
#  'fc2_023678/bias/adam_023678/read',
#  'fc2_023678/bias/adam_023678_1/Initializer/zeros',
#  'fc2_023678/bias/adam_023678_1',
#  'fc2_023678/bias/adam_023678_1/Assign',
#  'fc2_023678/bias/adam_023678_1/read',
#  'output_023678/kernel/adam_023678/Initializer/zeros',
#  'output_023678/kernel/adam_023678',
#  'output_023678/kernel/adam_023678/Assign',
#  'output_023678/kernel/adam_023678/read',
#  'output_023678/kernel/adam_023678_1/Initializer/zeros',
#  'output_023678/kernel/adam_023678_1',
#  'output_023678/kernel/adam_023678_1/Assign',
#  'output_023678/kernel/adam_023678_1/read',
#  'output_023678/bias/adam_023678/Initializer/zeros',
#  'output_023678/bias/adam_023678',
#  'output_023678/bias/adam_023678/Assign',
#  'output_023678/bias/adam_023678/read',
#  'output_023678/bias/adam_023678_1/Initializer/zeros',
#  'output_023678/bias/adam_023678_1',
#  'output_023678/bias/adam_023678_1/Assign',
#  'output_023678/bias/adam_023678_1/read',
#  'train_023678/adam_023678/learning_rate',
#  'train_023678/adam_023678/beta1',
#  'train_023678/adam_023678/beta2',
#  'train_023678/adam_023678/epsilon',
#  'train_023678/adam_023678/update_conv2d/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_conv2d/bias/ApplyAdam',
#  'train_023678/adam_023678/update_conv2d_1/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_conv2d_1/bias/ApplyAdam',
#  'train_023678/adam_023678/update_fc1/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_fc1/bias/ApplyAdam',
#  'train_023678/adam_023678/update_fc2/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_fc2/bias/ApplyAdam',
#  'train_023678/adam_023678/update_fc2_023678/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_fc2_023678/bias/ApplyAdam',
#  'train_023678/adam_023678/update_output_023678/kernel/ApplyAdam',
#  'train_023678/adam_023678/update_output_023678/bias/ApplyAdam',
#  'train_023678/adam_023678/mul',
#  'train_023678/adam_023678/Assign',
#  'train_023678/adam_023678/mul_1',
#  'train_023678/adam_023678/Assign_1',
#  'train_023678/adam_023678',
#  'eval_023678/in_top_k/InTopKV2/k',
#  'eval_023678/in_top_k/InTopKV2',
#  'eval_023678/Cast',
#  'eval_023678/Const',
#  'eval_023678/Mean',
#  'init_023678/init',
#  'init_023678/save/Const',
#  'init_023678/save/SaveV2/tensor_names',
#  'init_023678/save/SaveV2/shape_and_slices',
#  'init_023678/save/SaveV2',
#  'init_023678/save/control_dependency',
#  'init_023678/save/RestoreV2/tensor_names',
#  'init_023678/save/RestoreV2/shape_and_slices',
#  'init_023678/save/RestoreV2',
#  'init_023678/save/Assign',
#  'init_023678/save/RestoreV2_1/tensor_names',
#  'init_023678/save/RestoreV2_1/shape_and_slices',
#  'init_023678/save/RestoreV2_1',
#  'init_023678/save/Assign_1',
#  'init_023678/save/RestoreV2_2/tensor_names',
#  'init_023678/save/RestoreV2_2/shape_and_slices',
#  'init_023678/save/RestoreV2_2',
#  'init_023678/save/Assign_2',
#  'init_023678/save/RestoreV2_3/tensor_names',
#  'init_023678/save/RestoreV2_3/shape_and_slices',
#  'init_023678/save/RestoreV2_3',
#  'init_023678/save/Assign_3',
#  'init_023678/save/RestoreV2_4/tensor_names',
#  'init_023678/save/RestoreV2_4/shape_and_slices',
#  'init_023678/save/RestoreV2_4',
#  'init_023678/save/Assign_4',
#  'init_023678/save/RestoreV2_5/tensor_names',
#  'init_023678/save/RestoreV2_5/shape_and_slices',
#  'init_023678/save/RestoreV2_5',
#  'init_023678/save/Assign_5',
#  'init_023678/save/RestoreV2_6/tensor_names',
#  'init_023678/save/RestoreV2_6/shape_and_slices',
#  'init_023678/save/RestoreV2_6',
#  'init_023678/save/Assign_6',
#  'init_023678/save/RestoreV2_7/tensor_names',
#  'init_023678/save/RestoreV2_7/shape_and_slices',
#  'init_023678/save/RestoreV2_7',
#  'init_023678/save/Assign_7',
#  'init_023678/save/RestoreV2_8/tensor_names',
#  'init_023678/save/RestoreV2_8/shape_and_slices',
#  'init_023678/save/RestoreV2_8',
#  'init_023678/save/Assign_8',
#  'init_023678/save/RestoreV2_9/tensor_names',
#  'init_023678/save/RestoreV2_9/shape_and_slices',
#  'init_023678/save/RestoreV2_9',
#  'init_023678/save/Assign_9',
#  'init_023678/save/RestoreV2_10/tensor_names',
#  'init_023678/save/RestoreV2_10/shape_and_slices',
#  'init_023678/save/RestoreV2_10',
#  'init_023678/save/Assign_10',
#  'init_023678/save/RestoreV2_11/tensor_names',
#  'init_023678/save/RestoreV2_11/shape_and_slices',
#  'init_023678/save/RestoreV2_11',
#  'init_023678/save/Assign_11',
#  'init_023678/save/RestoreV2_12/tensor_names',
#  'init_023678/save/RestoreV2_12/shape_and_slices',
#  'init_023678/save/RestoreV2_12',
#  'init_023678/save/Assign_12',
#  'init_023678/save/RestoreV2_13/tensor_names',
#  'init_023678/save/RestoreV2_13/shape_and_slices',
#  'init_023678/save/RestoreV2_13',
#  'init_023678/save/Assign_13',
#  'init_023678/save/RestoreV2_14/tensor_names',
#  'init_023678/save/RestoreV2_14/shape_and_slices',
#  'init_023678/save/RestoreV2_14',
#  'init_023678/save/Assign_14',
#  'init_023678/save/RestoreV2_15/tensor_names',
#  'init_023678/save/RestoreV2_15/shape_and_slices',
#  'init_023678/save/RestoreV2_15',
#  'init_023678/save/Assign_15',
#  'init_023678/save/RestoreV2_16/tensor_names',
#  'init_023678/save/RestoreV2_16/shape_and_slices',
#  'init_023678/save/RestoreV2_16',
#  'init_023678/save/Assign_16',
#  'init_023678/save/RestoreV2_17/tensor_names',
#  'init_023678/save/RestoreV2_17/shape_and_slices',
#  'init_023678/save/RestoreV2_17',
#  'init_023678/save/Assign_17',
#  'init_023678/save/RestoreV2_18/tensor_names',
#  'init_023678/save/RestoreV2_18/shape_and_slices',
#  'init_023678/save/RestoreV2_18',
#  'init_023678/save/Assign_18',
#  'init_023678/save/RestoreV2_19/tensor_names',
#  'init_023678/save/RestoreV2_19/shape_and_slices',
#  'init_023678/save/RestoreV2_19',
#  'init_023678/save/Assign_19',
#  'init_023678/save/RestoreV2_20/tensor_names',
#  'init_023678/save/RestoreV2_20/shape_and_slices',
#  'init_023678/save/RestoreV2_20',
#  'init_023678/save/Assign_20',
#  'init_023678/save/RestoreV2_21/tensor_names',
#  'init_023678/save/RestoreV2_21/shape_and_slices',
#  'init_023678/save/RestoreV2_21',
#  'init_023678/save/Assign_21',
#  'init_023678/save/RestoreV2_22/tensor_names',
#  'init_023678/save/RestoreV2_22/shape_and_slices',
#  'init_023678/save/RestoreV2_22',
#  'init_023678/save/Assign_22',
#  'init_023678/save/RestoreV2_23/tensor_names',
#  'init_023678/save/RestoreV2_23/shape_and_slices',
#  'init_023678/save/RestoreV2_23',
#  'init_023678/save/Assign_23',
#  'init_023678/save/RestoreV2_24/tensor_names',
#  'init_023678/save/RestoreV2_24/shape_and_slices',
#  'init_023678/save/RestoreV2_24',
#  'init_023678/save/Assign_24',
#  'init_023678/save/RestoreV2_25/tensor_names',
#  'init_023678/save/RestoreV2_25/shape_and_slices',
#  'init_023678/save/RestoreV2_25',
#  'init_023678/save/Assign_25',
#  'init_023678/save/RestoreV2_26/tensor_names',
#  'init_023678/save/RestoreV2_26/shape_and_slices',
#  'init_023678/save/RestoreV2_26',
#  'init_023678/save/Assign_26',
#  'init_023678/save/RestoreV2_27/tensor_names',
#  ...]

# %%
import math

with tf.Session() as sess:
    saver.restore(sess, "./my_model_1459.ckpt")  
    getActivations(tf.get_default_graph().get_tensor_by_name("conv/conv2d_2/Conv2D:0"), X_1459_test[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'inputs/keep_prob' with dtype float
# 	 [[Node: inputs/keep_prob = Placeholder[dtype=DT_FLOAT, shape=<unknown>, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-18-d82f943b0197> in <module>()
#       3 with tf.Session() as sess:
#       4     saver.restore(sess, "./my_model_1459.ckpt")
# ----> 5     getActivations(tf.get_default_graph().get_tensor_by_name("conv/conv2d_2/Conv2D:0"), X_1459_test[0])
#
# <ipython-input-3-6eac6e728d5e> in getActivations(layer, stimuli)
#      11
#      12 def getActivations(layer,stimuli):
# ---> 13     units = sess.run(layer,feed_dict={X:np.reshape(stimuli,[1,784],order='F')})
#      14     plotNNFilter(units)
#      15
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'inputs/keep_prob' with dtype float
# 	 [[Node: inputs/keep_prob = Placeholder[dtype=DT_FLOAT, shape=<unknown>, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# Caused by op 'inputs/keep_prob', defined at:
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-6f13fce8cc6f>", line 5, in <module>
#     restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/training/saver.py", line 1810, in import_meta_graph
#     **kwargs)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/framework/meta_graph.py", line 660, in import_scoped_meta_graph
#     producer_op_list=producer_op_list)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/framework/importer.py", line 313, in import_graph_def
#     op_def=op_def)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/Users/trungnguyen/anaconda/envs/py34/lib/python3.4/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): You must feed a value for placeholder tensor 'inputs/keep_prob' with dtype float
# 	 [[Node: inputs/keep_prob = Placeholder[dtype=DT_FLOAT, shape=<unknown>, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]

# %%
[n.name for n in tf.get_default_graph().as_graph_def().node]

# %% [markdown]
# ### Visualize the convolution kernels

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_1459.ckpt")
    # plotConvLayerWeights(...)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_1459.ckpt

# %% [markdown]
# ## Show the Execution Graph

# %%
reset_graph()

# restore the graph of 1459
restore_saver = tf.train.import_meta_graph("./my_model_1459.ckpt.meta")

show_graph(tf.get_default_graph())
